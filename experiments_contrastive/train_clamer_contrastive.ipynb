# %% [markdown]
# # Train Clamer Model with Pre-setting Vocab

# %%
# change to the directory of the script
# %cd ..
# Out:
# /home/hudongcheng/Desktop/bo_osda_generator

# %%
import numpy as np
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.nn import functional as F
from tqdm import tqdm
from datetime import datetime
from torch.utils.tensorboard import SummaryWriter
import torch.backends.cudnn as cudnn

# import custom modules
from datasets.data_loader import *
from models.clamer import *
from models.loss import InfoNCELoss
from models.trfm import *
from utils.utils import *
from utils.plot_figures import *
from utils.metrics import *
from utils.build_vocab import *

# %%
cudnn.benchmark = True
cudnn.enabled = True

train_loss_history = []
train_acc_history = []
test_loss_history = []
test_acc_history = []
train_ce_loss_history = []
test_ce_loss_history = []
train_info_loss_history = []
test_info_loss_history = []

log_dir = './logs/'
save_best_weight_path = './checkpoints/'

now = datetime.now().strftime('%Y-%m-%d-%H-%M-%S')

# %%
PAD = 0
UNK = 1
EOS = 2
SOS = 3
MASK = 4
MAX_LEN = 220

# %%
# read the data from the file
train_data = pd.read_csv('./data/train_contrastive_dataset.csv')
test_data = pd.read_csv('./data/test_contrastive_dataset.csv')

vocab = WordVocab.load_vocab('./model_hub/vocab.pkl')
print('the vocab size is :', len(vocab))

charlen = len(vocab)
print('the total num of charset is :', charlen)
# Out:
# the vocab size is : 45
# the total num of charset is : 45

# %%
# hyperparameters
d_model = 128
head = 4
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
batch_size = 64
epoch = 10

# %%
# create the dataset and dataloader
# train_dataset = Contrastive_Seq2seqDataset(train_data, vocab, MAX_LEN)
# test_dataset = Contrastive_Seq2seqDataset(test_data, vocab, MAX_LEN)
train_dataset = Contrastive_Seq2seqDataset_random(train_data, vocab, MAX_LEN)
test_dataset = Contrastive_Seq2seqDataset_random(test_data, vocab, MAX_LEN)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# load model
model = GptCovd(d_model=d_model, charlen=charlen, device=device, head=head).to(device, non_blocking=True)

# load model
trfm = TrfmSeq2seq(charlen, 256, charlen, 4).to(device)
trfm.load_state_dict(torch.load('./model_hub/trfm_new_2_10000.pkl'))
trfm.eval()

# set trfm gradient to false which won't be updated
for param in trfm.parameters():
    param.requires_grad = False

# loss
loss_func = torch.nn.CrossEntropyLoss(ignore_index=PAD)
optim = torch.optim.Adam(model.parameters(), lr=6e-4)
total = sum(p.numel() for p in model.parameters())
print('total parameters: %0.2fM' % (total / 1e6))
# Out:
# 100%|██████████| 144938/144938 [00:00<00:00, 902005.81it/s]
# 100%|██████████| 144938/144938 [00:00<00:00, 808381.27it/s]
# 100%|██████████| 144938/144938 [00:02<00:00, 51357.44it/s]
# 100%|██████████| 14803/14803 [00:00<00:00, 1678424.58it/s]
# 100%|██████████| 14803/14803 [00:00<00:00, 1081941.28it/s]
# 100%|██████████| 14803/14803 [00:00<00:00, 51130.80it/s]
# total parameters: 1.34M

# %%
# train function
def train(model, trfm, train_dataloader, loss_func, optim, device, weight=0.1):
    model.train()
    total_loss = 0
    total_loss_crossentropy = 0
    total_loss_infonce = 0
    total_acc = 0
    total_num = 0
    for i, (zeo, syn, tgt, positive_smiles, negative_smiles) in enumerate(tqdm(train_dataloader)):
        zeo = zeo.to(device)
        syn = syn.to(device)
        tgt = tgt.to(device)
        positive_smiles = positive_smiles.to(device)
        negative_smiles = negative_smiles.to(device)
        
        tgt_input = tgt[:, :-1].contiguous()
        tgt_label = tgt[:, 1:].contiguous()
        
        # forward
        optim.zero_grad()
        # ignore the first two tokens becauese thay are condition tokens
        output = model(zeo, syn, tgt_input)
        logits = output[:, 2:, :].to(device, non_blocking=True).contiguous()
        
        # Compute CrossEntropy Loss
        logits_reshaped = logits.view(-1, logits.size(-1))
        tgt_label_reshaped = tgt_label.view(-1)
        loss_ce = loss_func(logits_reshaped, tgt_label_reshaped)
        
        # calculate the accuracy
        pred = torch.argmax(logits, dim=-1)
        num_correct = (pred == tgt_label) & (tgt_label != PAD)
        num_words = (tgt_label != PAD).sum().item()
        
        # Gumbel-Softmax Sampling
        # logits: [batch_size, seq_len, vocab_size]
        samples = F.gumbel_softmax(logits, tau=1.0, hard=True)
        samples_indices = samples.argmax(dim=-1) # [batch_size, seq_len]
        # add the start token to the samples
        stared_token = torch.ones(samples_indices.size(0), 1, dtype=torch.long).fill_(SOS).to(device)
        samples_indices = torch.cat([stared_token, samples_indices], dim=-1)
        
        # Compute InfoNCE Loss
        loss_infonce = InfoNCELoss(samples_indices, positive_smiles, negative_smiles, trfm, temperature=0.07)
        
        # combine the two loss
        loss = loss_ce + weight * loss_infonce
        
        # backward
        loss.backward()
        optim.step()
        
        # statistics
        total_loss += loss.item()
        total_loss_crossentropy += loss_ce.item()
        total_loss_infonce += loss_infonce.item()
        total_acc += num_correct.sum().item()
        total_num += num_words
    return total_loss / len(train_dataloader), total_acc / total_num, total_loss_crossentropy / len(train_dataloader), total_loss_infonce / len(train_dataloader)

# %%
def evaluate(model, trfm, test_dataloader, loss_func, device, weight=0.1):
    model.eval()
    total_loss = 0
    total_loss_crossentropy = 0
    total_loss_infonce = 0
    total_acc = 0
    total_num = 0
    with torch.no_grad():
        for i, (zeo, syn, tgt, positive_smiles, negative_smiles) in enumerate(tqdm(test_dataloader)):
            zeo = zeo.to(device)
            syn = syn.to(device)
            tgt = tgt.to(device)
            positive_smiles = positive_smiles.to(device)
            negative_smiles = negative_smiles.to(device)
            
            tgt_input = tgt[:, :-1].contiguous()
            tgt_label = tgt[:, 1:].contiguous()
            
            # forward
            # ignore the first two tokens becauese thay are condition tokens
            output = model(zeo, syn, tgt_input)
            logits = output[:, 2:, :].to(device, non_blocking=True).contiguous()
            
            # Compute CrossEntropy Loss
            logits_reshaped = logits.view(-1, logits.size(-1))
            tgt_label_reshaped = tgt_label.view(-1)
            loss_ce = loss_func(logits_reshaped, tgt_label_reshaped)
            
            # calculate the accuracy
            pred = torch.argmax(logits, dim=-1)
            num_correct = (pred == tgt_label) & (tgt_label != PAD)
            num_words = (tgt_label != PAD).sum().item()
            
            # Gumbel-Softmax Sampling
            # logits: [batch_size, seq_len, vocab_size]
            samples = F.gumbel_softmax(logits, tau=1.0, hard=True)
            samples_indices = samples.argmax(dim=-1) # [batch_size, seq_len]
            # add the start token to the samples
            stared_token = torch.ones(samples_indices.size(0), 1, dtype=torch.long).fill_(SOS).to(device)
            samples_indices = torch.cat([stared_token, samples_indices], dim=-1)
            
            # Compute InfoNCE Loss
            loss_infonce = InfoNCELoss(samples_indices, positive_smiles, negative_smiles, trfm, temperature=0.07)
            
            # combine the two loss
            loss = loss_ce + loss_infonce
            
             # statistics
            total_loss += loss.item()
            total_loss_crossentropy += loss_ce.item()
            total_loss_infonce += loss_infonce.item()
            total_acc += num_correct.sum().item()
            total_num += num_words
    return total_loss / len(test_dataloader), total_acc / total_num, total_loss_crossentropy / len(test_dataloader), total_loss_infonce / len(test_dataloader)

# %%
# # train the model
# for i in range(epoch):
#     train_loss, train_acc, train_ce, train_info = train(model, trfm, train_dataloader, loss_func, optim, device)
#     # train_loss, train_acc, train_ce, train_info = train(model, trfm, test_dataloader, loss_func, optim, device)
#     train_loss_history.append(train_loss)
#     train_acc_history.append(train_acc)
#     train_ce_loss_history.append(train_ce)
#     train_info_loss_history.append(train_info)
#     print('epoch: %d, train loss: %.4f, train acc: %.4f, train crossentropy loss: %.4f, train infonce loss: %.4f' % (i, train_loss, train_acc, train_ce, train_info))
#     test_loss, test_acc, test_ce, test_info = evaluate(model, trfm, test_dataloader, loss_func, device)
#     test_loss_history.append(test_loss)
#     test_acc_history.append(test_acc)
#     test_ce_loss_history.append(test_ce)
#     test_info_loss_history.append(test_info)
#     print('epoch: %d test loss: %.4f, test acc: %.4f, test crossentropy loss: %.4f, test infonce loss: %.4f' % (i, test_loss, test_acc, test_ce, test_info))
#     if i == 0:
#         best_acc = test_acc
#     if test_acc > best_acc:
#         best_acc = test_acc
#         torch.save(model.state_dict(), save_best_weight_path + 'best_clamer_contrastive_model.pth')
#     torch.save(model.state_dict(), save_best_weight_path + 'last_clamer_contrastive_model.pth')
    
#     # save every epoch model to clamer folder
#     torch.save(model.state_dict(), save_best_weight_path + '/clamer/clamer_contrastive_model_' + str(i) + '.pth')

# %%
# load the last model
model = GptCovd(d_model=d_model, charlen=charlen, device=device, head=head).to(device, non_blocking=True)
model.load_state_dict(torch.load('./checkpoints/clamer/clamer_contrastive_model_9.pth'))
# Out:
# <All keys matched successfully>

# %%
def generate_clamer(model, start_sequence, zeo, syn, max_length, vocab, device, temperature=1.0, top_k=0):
    """
    Autoregressive generation process for a GPT model.

    Args:
        model (CLAMER): The pre-trained GPT model for token generation.
        start_sequence (torch.Tensor): The initial sequence to start generation (batch_size, seq_length).
        zeo (torch.Tensor): The zeolite condition tensor.
        syn (torch.Tensor): The synthesis condition tensor.
        max_length (int): The maximum length of the generated sequence.
        vocab: The vocabulary object for encoding and decoding SMILES strings.
        device (torch.device): The device on which to run the generation.
        temperature (float): Temperature parameter for sampling; higher values increase randomness.
        top_k (int): Limits sampling to top-k logits; if 0, no top-k sampling is applied.

    Returns:
        List[str]: A list of generated SMILES strings.
    """
    model.eval()
    batch_size = start_sequence.size(0)
    generated_sequences = start_sequence.clone().to(device)  # Clone and move to device
    # expand generated_sequences to the max_length with padding tokens
    padding = torch.full((batch_size, max_length - generated_sequences.size(1)), PAD, dtype=torch.long).to(device)
    generated_sequences_input = torch.cat([generated_sequences, padding], dim=1)[:,:-1].to(device)
    
    with torch.no_grad():
        # Forward pass through the
        for current_len in range(max_length - start_sequence.size(1)):
            
            # Forward pass through the model
            logits = model(zeo, syn, generated_sequences_input)
            # Extract the logits for the last time step
            next_token_logits = logits[:, -1, :]  # (batch_size, vocab_size)

            # Apply temperature scaling
            next_token_logits = next_token_logits / temperature

            # Apply top-k filtering
            if top_k > 0:
                top_k_logits, top_k_indices = torch.topk(next_token_logits, top_k, dim=-1)
                mask = torch.full_like(next_token_logits, float('-inf'))
                mask.scatter_(dim=-1, index=top_k_indices, src=top_k_logits)
                next_token_logits = mask

            # Convert logits to probabilities
            next_token_probs = F.softmax(next_token_logits, dim=-1)

            # Sample from the probability distribution
            next_token = torch.multinomial(next_token_probs, num_samples=1)  # (batch_size, 1)
            
            # Get the most likely next token
            # next_token = torch.argmax(next_token_logits, dim=-1, keepdim=True)

            # Append the generated token to the sequence
            generated_sequences = torch.cat([generated_sequences, next_token], dim=1)
            # update the input sequence for the next iteration
            generated_sequences_input[:, current_len] = next_token.squeeze(1)

            # Check if all sequences have reached the end token
            if all(next_token[i].item() == EOS for i in range(batch_size)):
                break

    # Decode the generated sequences into SMILES strings
    generated_smiles = []
    for seq in generated_sequences:
        # Convert indices to characters, ignoring padding and start tokens
        # check if the generated sequence contains the end token, if meet, stop decoding
        smiles = ''
        for idx in seq:
            if idx.item() == EOS:
                break
            elif idx.item() != PAD and idx.item() != SOS:
                smiles += vocab.itos[idx.item()]
        generated_smiles.append(smiles)

    return generated_smiles

# %%
def sample_clamer(temp, model, sample_dataloader, device, vocab):
    '''ArithmeticError
    Generate SMILES strings using the trained GPT model with sampling.
    
    Args:
        temp (float): The temperature parameter for sampling.
        model (CLAMER): The pre-trained GPT model for token generation.
        sample_dataloader (DataLoader): The data loader for the SMILES dataset.
        device (torch.device): The device on which to run the generation.
        vocab: The vocabulary object for encoding and decoding SMILES strings.
    
    Returns:
        List[float]: A list of negative log-likelihoods for the generated SMILES strings.
        List[str]: A list of generated SMILES strings.
    '''
    sample_nll_total = []
    smiles_gen_total = []
    with torch.no_grad():
        for batch_idx, (zeo, syn, tgt, positive_smiles, negative_smiles) in enumerate(tqdm(sample_dataloader)):
            # Generate the target sequence for the model
            target = [SOS] + [PAD] * 218
            tgt_seq = torch.LongTensor(target).unsqueeze(0).expand(zeo.size(0), len(target)).to(device)
            batch_size = zeo.size(0)
            # Move input tensors to the device
            zeo, syn = zeo.to(device), syn.to(device)
            smiles_gen = [[''] * batch_size][0]
            sample_nll = [0] * batch_size
            finished = np.array([False] * batch_size, dtype=object)
            end_char = '<eos>'
            for i in range(218):
                net_out = model(zeo, syn, tgt_seq)[:, i + 2, :]
                o = F.softmax(net_out, dim=-1).cpu().detach().numpy()
                # sample temp
                if temp != 0:
                    temp = abs(temp)  # No negative values
                    next_char_probs = np.log(o) / temp
                    next_char_probs = np.exp(next_char_probs)
                    next_char_probs = next_char_probs.astype(float)
                    next_char_probs = (next_char_probs.T / (next_char_probs.sum(axis=1))).T
                    sampleidc = torch.tensor(
                        [np.random.multinomial(1, next_char_prob, 1).argmax() for next_char_prob in
                            next_char_probs])
                else:
                    sampleidc = torch.tensor(np.argmax(o, axis=1))

                samplechars = [vocab.itos[idx] for idx in sampleidc.numpy()]

                for idx, samplechar in enumerate(samplechars):
                    if not finished[idx]:
                        if samplechar != end_char:
                            # Append the SMILES with the next character
                            smiles_gen[idx] += samplechar
                            tgt_seq[:, i + 1] = sampleidc.to(device)
                            # Calculate negative log likelihood for the selected character
                            sample_nll[idx] -= np.log(o[idx][sampleidc[idx]])
                        else:
                            finished[idx] = True
                            # print("SMILES has finished at %i" %i)
                # If all SMILES are finished, i.e. the end_char "<eos>" has been generated, stop the generation
            if finished.sum() == len(finished):
                sample_nll_total += sample_nll
                smiles_gen_total += smiles_gen
                    
    return sample_nll_total, smiles_gen_total

# %%
# generate the smiles for the test dataset
sample_nll_total, generated_smiles = sample_clamer(temp=0.7, model=model, sample_dataloader=test_dataloader, device=device, vocab=vocab)
target_smiles = []
for i, (zeo, syn, tgt, _, _) in enumerate(tqdm(test_dataloader)):
    tgt = tgt.to(device)
    # convert the tgt to smiles
    tgt_smiles = []
    for seq in tgt:
        smiles = ''
        for idx in seq:
            if idx.item() == EOS:
                break
            elif idx.item() != PAD and idx.item() != SOS:
                smiles += vocab.itos[idx.item()]
        tgt_smiles.append(smiles)
    target_smiles.extend(tgt_smiles)
print('the total num of target smiles is :', len(target_smiles))
# Out:
# 100%|██████████| 232/232 [06:56<00:00,  1.80s/it]
# 100%|██████████| 232/232 [00:39<00:00,  5.87it/s]
# the total num of target smiles is : 14803

# %%
print('the generated smiles are :', generated_smiles[1:3])
print('the target smiles are :', target_smiles[1:3])
# Out:
# the generated smiles are : ['C(CCC[N+]1(C2CCCC1CC2)C)C[N+]1(C2CCC1CCC2)C', '[N+]1(CCCCC1C)(C)CC']
# the target smiles are : ['C(CCC[n+]1ccn(c1)C)CCCC[n+]1ccn(C)c1', 'c1[n+](cn(c1)C)CCCCCCCC[n+]1cn(cc1)C']

# %%
# calculate the metrics
print('Validity rate:', validity_rate(generated_smiles))
print('Uniqueness rate:', uniqueness_rate(generated_smiles))
print('Novelty rate:', novelty_rate(generated_smiles, target_smiles))
print('Reconstructability rate:', reconstructability_rate(generated_smiles, target_smiles))
print('Novelty rate:', novelty_rate(generated_smiles, target_smiles))
print('IntDiv:', IntDiv(generated_smiles))
# print('KL-divergence:', KL_divergence(target_smiles), generated_smiles))
print('FCD score:', FCD_score(target_smiles, generated_smiles))
# Out:
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC(C)(N2CCCCCN(C(C)CC)C(C)CC)CC'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C1CCC(C)C[N+]1(C)CC)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1CCC(C)C[N+]1(C)CC)C' for input: 'C1CCC(C)C[N+]1(C)CC)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC(C[P+](C(C)C)(C)C)(C)[n+](c1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CCCC(C1)N2CCCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC3[N+](C)(CCCCCC[N+](C)(C)CCCCCCCCCCCCCCCC)C1CCCCCCC2CC1'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 4 5 6
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](C1CC[N+](CCC)(CC2)CCC)(CCC)CCC1'
# [13:22:05] SMILES Parse Error: extra open parentheses for input: 'c1(n(C)c[n+](c1)CCCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C(C)C)N(CCCCCN(CC(C)C)CCN(C)CC1)C'
# [13:22:05] SMILES Parse Error: syntax error while parsing: CC(CCC(C)[N+]1(C)CCCCC1)N+]1(C)CCCCC1
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'CC(CCC(C)[N+]1(C)CCCCC1)N+]1(C)CCCCC1' for input: 'CC(CCC(C)[N+]1(C)CCCCC1)N+]1(C)CCCCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2C(CCCC1)[N+](CC)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)(CC)N(CCCCCN(C(C)CC)C(C)CC1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CCC([N+]2(C)CCCCC2)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2CC3CC(CC4[N+]3(C)CCCCC4C3)C12'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3CCCCN3CC(C3[N+](C3)(C)CCCC3)C2CCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC23CC(CC2(CC1[N+]1(CCCCC1C2)C)CC)[N+](C)(CCCC2)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(CC4CCCC([N+]3(C)CC)C2)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(C3CCCC[N+]3(C)CC(C1)[N+]1(C)C(CCCC1)C2)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC(CN4C3CCCC4)C2[N+]3(CCCCC3C1)CCCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC2C3CC(C[N+]3(C)CCCCC32)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3CC(C4C[N+]4(C)CCCCC4C3)CN2CCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(CCCC2CC[N+](C)(C)CCCCCC)CC[N+](C)(CC1)CCCCCC'
# [13:22:05] Explicit valence for atom # 0 N, 4, is greater than permitted
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 18 21 22
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2C1C[N+]1(CCCCC1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2(CC[N+](C1)(C)C)O'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C([N+]2(CCCCCC[N+]3(CCCCC3)C)CCC1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC[N+]1(C(C)C)CC(CC)C'
# [13:22:05] Explicit valence for atom # 1 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 3 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](CCC)(C)CCC(C)[N+]2(C)CCCCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC1(C)C2CC1CCC[N+](CC)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(CN(CCCCC)CCCCCN(CCCCC)CCCCC)CCCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[N+]1(C)(CCCCCC[N+]2(C)C4CCCC3CC4)C2CCCC1CC2'
# [13:22:05] Explicit valence for atom # 5 O, 3, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1OCC[N+](C1)(CC2C1CC3CCCC[N+]3(C)C)CC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C[N+]1(CCC)CCC([N+]2(CCCC2)CCCC2)CC1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+](C)(C)CCCCCC[N+]2(CCCCC2)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 6
# [13:22:05] Explicit valence for atom # 18 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: syntax error while parsing: (C(C)CC[P+](CCC(C)[N+](CCCCCC)(C)C)(C)C)CCCCCCCCCC
# [13:22:05] SMILES Parse Error: Failed parsing SMILES '(C(C)CC[P+](CCC(C)[N+](CCCCCC)(C)C)(C)C)CCCCCCCCCC' for input: '(C(C)CC[P+](CCC(C)[N+](CCCCCC)(C)C)(C)C)CCCCCCCCCC'
# [13:22:05] Explicit valence for atom # 10 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC[N+](C)(CC1CCCC2CC[N+](C)(CC2)CCCCC)CC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC1[N+]2(CCCC1)CCCC1CC[N+](CCC)(CC1)CCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC1[N+]2(CCCCCC[N+]3(C)C4CCCC3CC4)C(C)CCC1'
# [13:22:05] Explicit valence for atom # 12 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(CCCCC[N+](CCCC)(CCCC)CCCC)Cn1cc[n+](CCCCCC)CCCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)CC(C)N(CCCCCN(CC(C)C)CC1)C'
# [13:22:05] Explicit valence for atom # 14 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(CCCCC2)CCC1CC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC([N+]2(CCCCCC[N+]3(C)C4CCCC3CC4)C)CC1'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C(CCC)[N+](CCCC)(CCCC)CCCC)CCC
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C(CCC)[N+](CCCC)(CCCC)CCCC)CCC' for input: 'C(CCC)[N+](CCCC)(CCCC)CCCC)CCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(CC4CCCC([N+]1(C)CC)C3)C2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3CCCC[N+]3(CC3CC(C2)C1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCN2CC3C4[N+](CC(C4)CC(C3)C21)(C)CCCC4'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(CC)C(CC1)C1N(CC2C1)CCCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCN1CC1CC2C[N+]2(CCCCC21)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)CC(N(CCCCC)C(CC)C)CCN(CC(C)C1)CC'
# [13:22:05] Explicit valence for atom # 20 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12[N+](C)(CC3CC(C1)CC(C)(C2)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2C3CCC(C=1)C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+](C)(C)C1CCCCCC2'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8
# [13:22:05] Explicit valence for atom # 6 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2C3CC(CC3(C)C)[N+](C)(C)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1CC(C2)([n+]1ccn(C34CC5CC(C3)CC(C5)C4)c1)C2'
# [13:22:05] Explicit valence for atom # 19 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 15 N, 4, is greater than permitted
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 5 6 7
# [13:22:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C1)CC(C2)(C2)[N+](C)(C)C'
# [13:22:05] Explicit valence for atom # 1 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 7 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1(CC2CCC1CC2)ccnc[N+]1(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1(C2CC(CC2)C1)ccccc1'
# [13:22:05] Explicit valence for atom # 0 O, 3, is greater than permitted
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2
# [13:22:05] Explicit valence for atom # 5 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC(C)(C)C2C(C)(C)C[N+]1(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CCCC(CCC2C(C)(C[N+](C)(C)C)C1)C2'
# [13:22:05] SMILES Parse Error: syntax error while parsing: C(CCCCCCCCCC)CCC[N+](CC[N+](CC[N(C)(C)C)(C)CC1)(C)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C(CCCCCCCCCC)CCC[N+](CC[N+](CC[N(C)(C)C)(C)CC1)(C)C' for input: 'C(CCCCCCCCCC)CCC[N+](CC[N+](CC[N(C)(C)C)(C)CC1)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCC[N+](C)(C)C1CCCCC1'
# [13:22:05] Explicit valence for atom # 4 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[N+]1(CCCCCCCCC[N+]2(C)C3CCCC1CC3)(C)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C2)CC(C3)(n3c[n+](C45CC5CC(C4)CC(C5)C6)cc1)C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+](C)(C)C(C)CCC(C)[N+]2(C)CCCCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)[N+]1(CC)CC2CCC(C1)c1ccccc1'
# [13:22:05] Explicit valence for atom # 0 O, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)[N+]1(CC)CC2C3C(C4C[N+](CC43C[N+](CC42)(CC)CC)C=C1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[N+]1(CC2C(C3C4C=CC(C4C3C[N+](C)(C)C5)C21)C)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC5C(C=C3)C1C[N+](CC)(CC)C2)(CC)CC'
# [13:22:05] SMILES Parse Error: ring closure 4 duplicates bond between atom 7 and atom 8 for input: 'CC[N+]1(CC2C(C3C4C4C[N+](CC)(CC4C(C=C3)C2)C1)CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'N1(CC2CC(C[N+]3(CC2C)C)C1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C([N+]1(CC)CC2C(C3C=CC2C2C3C[N+](CC)(CC2C3)CC)C1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1=CC2C3C(C[N+](C3)(CC)CC)C1C1C3C[N+](CC)(C1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C[N+](CC)(CC2C2C3C(C3C[N+](CC)(CC32)CC)C=C1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C(C[N+](CC)(C2)CC)C2C3C(C[N+](C3)(CC)CC)C=C2C1C[N+](CC)(CC)CC3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC4C(C=C3)C2C[N+](C)(C)CC12)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC[N+]1(CC2C3C4C(C[N+](C4)(CC)CC4C(C=C3)C2C1)C)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C([N+]1(CC)CC2C(C3C=CC2C2C3C[N+](CC23)(CC)CC)C1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C[N+](CC3C(C=1)C1C3C[N+](CC)(CC)CC12)(CC)CC'
# [13:22:05] SMILES Parse Error: extra open parentheses for input: 'C1C[N+](CC2C3C4C[N+](CC)(CC)CC4C(C)C4C[N+](CC)(CC)CC4C21'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C(C[N+](C4)(CC)CC)C(C=1)C1C[N+](CC)(CC31)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1=CC2C3C[N+](CC3C1C1C2C2C[N+](C1)(CC)CC)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C(C[N+](C4)(CC)CC)C(C=1)C1C[N+](CC)(CC41)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C(C[N+](C4)(CC)CC)C(C=C1)C1C2C[N+](CC)(C1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1=CC2C3C(C[N+](C3)(CC)CC)C2C1C1C[N+](CC)(CC)CC12'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C[N+](CC)(CC4C(C3C[N+](CC32)(CC)CC)C=1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC3C(C=C2C)C2C1C[N+](C)(CC21)CC)(CC)CC'
# [13:22:05] SMILES Parse Error: ring closure 2 duplicates bond between atom 9 and atom 10 for input: 'C12C[N+](CC2C1C1C=CC2C2C[N+](CC21)(CC)CC)(CC)CC'
# [13:22:05] SMILES Parse Error: ring closure 2 duplicates bond between atom 0 and atom 19 for input: 'C12C3C=CC(C4C5C(C[N+](C5)(C)C)C3C[N+](C)(C)C5)C21'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C(C[N+](C1C2C=C1)(CC)CC)C[N+](CC)(CC)C4'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)[N+]1(CC)CC2C3C=CC(C)(C)C3C2C1C[N+](CC)(C2)CC'
# [13:22:05] SMILES Parse Error: ring closure 2 duplicates bond between atom 0 and atom 20 for input: 'C12C3C4C(C[N+](C4)(CC)CC)C(C3C[N+](CC)(CC)CC12)=C=C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C(C[N+](C3C2C=C1)(CC)CC)C1C3C[N+](CC)(C1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C=CC(C4C[N+](CC)(CC43)CC)C2C[N+](CC)(CC12)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C(C(C[N+]4(C)CCC1)C=C2)C3C[N+](CC)(CC)C2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'N12CC[N+](CC2)(CCCC[N+]23CC(C)C(CC1C)CC3)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C(C3C4C(C[N+](CC)(C4)CC)C=C3)C[N+](CC)(CC)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C([N+]1(CC)CC2C(C3C4C(C2C=C3)C2C[N+](CC)(C2)CC)C1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC4C(C=C3)C1C2C[N+](C)(CC)C2)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC4C(C=C3)C2C[N+](CC21)(CC)CC)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C(C3C4C[N+](CC)(CC4C3C2C=C3)CC)C[N+]1(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C[N+](CC)(CC4C(C=1)C1C[N+](CC12)(CC)CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C[N+](CC3C2C2C=1)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](CC2C3C(C1C2)C1C2C[N+](C3)(CC)CC)(CC)CC=C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC)(CC4C(C=C1)C1C[N+](CC)(CC21)CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC3C(C3C2C1C[N+](C3)(CC)CC)C=C2)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[N+]1(CCCC2C3C4C(C(C=C4)C3C2C1)C[N+](CC)(CC)C4)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C=CC(C4C[N+](CC34)(CC)CC)C2C[N+](CC12)(CC)CC'
# [13:22:05] SMILES Parse Error: ring closure 2 duplicates bond between atom 0 and atom 20 for input: 'C12C3C4C[N+](CC)(CC)CC4C(C3C[N+](CC)(CC)CC12)C=C2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)[N+]1(CC2C(C3(C)C=CC2(C)C3C[N+](CC)(CC)CC23)C1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[N+]1(CC2C3C4C(C(C=C3)C12)C1C2C[N+](C1)(CC)CC)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC3C(C(C2)C2C[N+](CC21)(CC)CC)(C=C2C)C)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C(C(C[N+]2(C)C)C1C=C2)C3C[N+](CC)(CC)C2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C([N+]1(CC2C3C(C4C[N+](CC4C3C(C2C1)C=C3)(CC)CC)C)CC)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+](CC)(CC)CC2C3C=CC(C21)C1C2C[N+](CC)(C1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C=CC(C3C[N+](CC)(CC32)CC)C2C1C[N+](CC21)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC3C(C=C2)C2C[N+](C1)(CC)CC)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C(C[N+](CC)(C4)CC)C(C=1)C1C[N+](CC)(CC12)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C[N+](CC)(CC3C(C=1)C1C2C[N+](CC)(CC12)CC)CC'
# [13:22:05] SMILES Parse Error: ring closure 3 duplicates bond between atom 1 and atom 2 for input: 'C12C3C3C4C(C[N+](C4)(CC)CC)C(C=C3)C2C[N+](C1)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C(C[N+]3(CCCCC3)C1)C1C=CC2C1C[N+](C)(CC21)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC3C(C3C4C[N+](CC)(C4)CC)C=C2C1C=C2)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C(C(C[N+](C)(C3)C)C1CC=C2)C[N+](C)(C)C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](CC)(CC)CC2C1C3C[N+](CC)(CC3C(C=C1)C2)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C(C[N+](C3)(CC)CC)C(C3C2C[N+](CC32)(CC)CC)C=1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](CC)(CC)CC2C1C1C(C2C=C1)C[N+](CC)(CC)C2'
# [13:22:05] SMILES Parse Error: ring closure 3 duplicates bond between atom 4 and atom 5 for input: 'C12C=CC(C3C3C[N+](C3)(CC)CC)C2C2C[N+](CC)(CC12)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C[N+](CC4C(C=1)C1C2C[N+](CC21)(CC)CC)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C(C3C=CC2C3C4C[N+](CC5C42C[N+](C)(C3)C)(CC)C)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C(C(C=C3)C2C1C[N+](C2)(CC)CC)C[N+](C4)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC4C(C=C3)C3C[N+](C)(CC32)C)(C)C'
# [13:22:05] Explicit valence for atom # 3 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCCC1[N+](CCC1)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(N)CCC'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 2 3 18 19 20
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(CC1CC[N+](C)(CC1)CCCC1)CC1CC[N+](C)(CC1)Cc1ccccc1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+](C)(C)CCCCCC[N+]2(CCCCC2)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](CCCCC1)(C)CCC(CCCC2CC[N+](C)(CC2)Cc2ccccc2)CC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C(C3C=CC3C2C3C[N+](C2)(CC)CC)C[N+](CC)(C1)CC'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 13 14 15 16 17
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1[n+](ccn1CC2CCCCC2)CC(C)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2(OC(CC1)CC)Cc1ccccc1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1cccc(C[N+]12CCN(CC2)CC1)c1ccccc1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CCC([N+]2(CC)C)C3'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 17
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 19 20 24
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C(C[N+](C3)(C)C)C(C=1)C1C3C[N+](C1)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C(CCCCCC1)Cn1c[n+](C2CCCCCCC2)cc1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2C(CCC2)C[N+]11CCCCCC[N+]1(C)CCCCC1'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 14 15 18
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 9 18 19
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC(Cn2c[n+](cc2)CCCC2)C1'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 7 8 9
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)C(CC)N(CCCC1)CC'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 16 17 18 32
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 8 26 27
# [13:22:05] Explicit valence for atom # 0 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 18 N, 4, is greater than permitted
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 13 14 15 21 22
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC[N+](C)(CC1)CCCCCC[N+]1(CCC(CC1)CCC2)C'
# [13:22:05] Explicit valence for atom # 30 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C[N+](C)(C)Cc1cc(C[N+](CCCCCC)(C)C)ccc(Cn2cc[N+](C)(C)CCCCCCN(C)C)cc2'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 14 16 17
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C3C[N+](CC3C(C=1)C1C2C2C[N+](C)(CC2C12)C)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C(C3C=CC2C2C3C[N+](CC23)(CC)CC)C[N+](C1)(CC)CC'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C(C)[N+]1(C)CCCCCC1)CCC(CCCC1CC[N+](C)(CC1)CCCC)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C(C)[N+]1(C)CCCCCC1)CCC(CCCC1CC[N+](C)(CC1)CCCC)C' for input: 'C(C)[N+]1(C)CCCCCC1)CCC(CCCC1CC[N+](C)(CC1)CCCC)C'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: CC[N+]1(C)CCCC2CCCCC21)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'CC[N+]1(C)CCCC2CCCCC21)C' for input: 'CC[N+]1(C)CCCC2CCCCC21)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCC1N1C(CCC2)CC[N+]1(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C[N+]3(CCCCC2)CCCCC2)CC(C)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+]2(CCCCC2)CC[N+]12CC(C)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC[N+](CCC1)(C)CCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1c(C[N+](C)(CC[N+]2(C)CCN(CC2)CC2)C)ccccc1'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C1CCCCC1N(CCCC)C)CCCCN1CCCCC1
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1CCCCC1N(CCCC)C)CCCCN1CCCCC1' for input: 'C1CCCCC1N(CCCC)C)CCCCN1CCCCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](C)(CC2C3C=CC(C12)C1C3C[N+](C)(CC3C12)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC3C(C3C4C(C23)C=C3)C=C1)(C)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 10 11 12 13
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 11 12 13 14 15
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1cc(ccc1Cn1cc[n+](C)c1C)cccc1F'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 16 17 18 19
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 2 4 5
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCN2C3CC4CC(CC4[N+](C)(CCCC4)C3)C12'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3[N+](C)(C(C2)CC3N2CCCCC3CC1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)[N+](CCC1C[N+](C)(C)CC1CC[N+](CC1)(C)C)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C)CCCCC2CC2[N+]3(C1CCCC2)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC1C2CC(C(C)(C)C1C)C[N+]12C(CCC1)CCCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2C(C)(C)C1CC1[N+]2(CCCCC1C)CC1CCC2CC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCC[N+]1(C)CC1CC(CC1)C2(C)C'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C1CCCC(C1)[N+](C)(C)CC1CCC2C(C2)(C1(C)C)C)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1CCCC(C1)[N+](C)(C)CC1CCC2C(C2)(C1(C)C)C)C' for input: 'C1CCCC(C1)[N+](C)(C)CC1CCC2C(C2)(C1(C)C)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C1CC[N+](CCCCC)(C)CC1)CC1CC(C2C1C(C2C1)CC[N+](C)(C)C2)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C(CC[N+](CC1)(CC)CCC)CC1CC[N+](CCC)(C1)CCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C(CC[N+]3(C1)C)CCCC3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(C)CC3C4C=CC(C4C3)C[N+](CC4)(C)C12'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C[N+](C3CC[N+](CC)(CC3)CC2C3)(CC)CCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CCCCN3CC(C2)[N+]2(CC)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CCCC[N+]3(CC1C3)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2CC3[N+]4(C)CCCCC4CC(C2)[N+]2(CC1)C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CCCC[N+]3(C)C1CC1CCCC[N+]13C(C2)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3[N+]4(C(CCCC4)CC([N+]1(C)C)C3)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2CC3[N+]4(C)CC(CC1C3)[N+]1(C)C(CCCC2)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C)CCCC1CC1CCCC[N+]13CCCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC2C(C)(C(C1)[N+]1(CCCCC1)CC)CC1CCC2C'
# [13:22:05] Explicit valence for atom # 1 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C[N+](C)(C)Cc1ccc(C[N+](C)(Cc2ccccc2)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC4CCCC[N+]24C)[N+]2(C)CCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(CC)C(CC3CC2CC2CC3)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+](C)(CCC1C[N+](CC1CC(C2)C)(C)C)CC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(N2CC[N+]3(CC)CCCCC3)CC3CCCC[N+](C12)(CC)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](C)(CCC2(C3CC[N+](C)(CC4C3)CCC)C1CC2)C'
# [13:22:05] SMILES Parse Error: syntax error while parsing: CCC[N+]1(CCC([CC1)C)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'CCC[N+]1(CCC([CC1)C)C' for input: 'CCC[N+]1(CCC([CC1)C)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 3 9 10 11 12
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 11 12 14 15
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2C(C1)C[N+](CC)(CC)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 3 4 5
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(CCCC2CC[N+](CC3CCCCC3)(C)CC2)CC[N+](Cc3ccc(C2)cc3)CCCC1'
# [13:22:05] Explicit valence for atom # 6 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C(CCCC[N+](C)(C)Cc1ccc(cc1)C[N+](C)(C)C)CC[N+](C)(CCCCCC[N+](CCCCCC[N+](C)(C)C)C)(C)C)C[N+](C)(C)(C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C(CCCC[N+](C)(C)Cc1ccc(cc1)C[N+](C)(C)C)CC[N+](C)(CCCCCC[N+](CCCCCC[N+](C)(C)C)C)(C)C)C[N+](C)(C)(C' for input: 'C(CCCC[N+](C)(C)Cc1ccc(cc1)C[N+](C)(C)C)CC[N+](C)(CCCCCC[N+](CCCCCC[N+](C)(C)C)C)(C)C)C[N+](C)(C)(C'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C(CCCCC[N+](C)(C)C)[N+](C)(C)CCCCCC[N+](C)(C)Cc1ccc(C[N+](C)(CCCCCC[N+](C)(C)C)C)(C)C)ccc1CCCCCCCC
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C(CCCCC[N+](C)(C)C)[N+](C)(C)CCCCCC[N+](C)(C)Cc1ccc(C[N+](C)(CCCCCC[N+](C)(C)C)C)(C)C)ccc1CCCCCCCC' for input: 'C(CCCCC[N+](C)(C)C)[N+](C)(C)CCCCCC[N+](C)(C)Cc1ccc(C[N+](C)(CCCCCC[N+](C)(C)C)C)(C)C)ccc1CCCCCCCC'
# [13:22:05] Explicit valence for atom # 28 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 18 N, 4, is greater than permitted
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 21 64 65
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1(C[N+](C)(CCCCCC[N+](C)(C)CCCCCCCCCCCCCCCC)C)CCCCCCCCCCCCCCCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1cc(ccn1)C[N+](C)(C)CCCCCC[N+](C)(C)Cc1ccc(C[N+](C)(C)CCCCCC[N+](C)(C)C)c1ccc(c1)C[N+](CCCCC[N+](C)(C)C)(C)C'
# [13:22:05] Explicit valence for atom # 21 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 8 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 32 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(CCCC[N+]12CCC(CC2)CCCCCCC1)CC[N+](CCCCCC[N+]2(CCCCCC[N+](C)(C)CCCCCCCC2)(C)C)CC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C[N+]1(CCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](C)(CCCCCC[N+](CCCCCCCCCCCCCCCC)C)(C)C)CCCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1c(ccc(C[N+](CCCCCCN(C)C)(C)C)c1)C[N+](C)(CCCCCC[N+](CCCCCC[N+](CCCCCCCCCCCCCCCC)(C)C)(C)C)cc1'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 32 33 34 35
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 33 51 52
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(CC[N+](C)(C)C)CCCC[N+](C)(C)Cc1ccc(C[N+](C)(C)CCCCCC[N+](C)(C)Cc2ccc(C[N+](C)(CCCCCC[N+](C)(C)C)C)cc2)C'
# [13:22:05] Explicit valence for atom # 16 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCC[N+](CCCCCC[N+]2(CCC(CC2)CCCC2CC[N+](C)(C1)CCCCCC[N+](C)(C)CCCCCCCCCCCCCCCC)C)(C)CC1CCCCCCCCC'
# [13:22:05] Explicit valence for atom # 8 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 33 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 33 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 8 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 13 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 31 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1(C[N+]2(C)CCC(CCCC3CC[N+](Cc4ccc(cc4)(C)CC3)CC2)C)ccc(cc1)CC2'
# [13:22:05] Explicit valence for atom # 6 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(CCC[N+](C)(C)C)C[N+](C)(C)Cc1ccc(C[N+](C)(C)CCCCCC[N+](C)(Cc2ccc(CN[N+](CCCCCC[N+](C)(C)C)(C)C)cc2)C)cc1C[N+](C)(C)(C)CCCCCCCCCCCCCCCCC[N+](C)(cc1)C'
# [13:22:05] Explicit valence for atom # 13 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 12 N, 4, is greater than permitted
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 9 10 11 41 42
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](CC)(CC)CC2C3C4C(C[N+](CC)(C4)CC)C1C=C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](C)(CC2C1C1C2C3C[N+](C)(CC3C1C=C2)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2(CC3CC(CC4C3)C2C3)[N+](C)(CCCC2)C1'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 12 13 14 15
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C)C(CC3CC2CC[N+]3(C)CCCCC32)CCC1'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C1C[N+]2(C)CCN1CC2)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1C[N+]2(C)CCN1CC2)C' for input: 'C1C[N+]2(C)CCN1CC2)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2[N+](C)(C3CC([N+]4(C)C)CN1C(C3)C)CCCC2'
# [13:22:05] SMILES Parse Error: ring closure 3 duplicates bond between atom 8 and atom 9 for input: 'C12[N+](CCCC1)(C1CC3[N+]3(C)C(CC2C1)CCCC3)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCC2[N+]3(CC)CCCCC3CC3CN2C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC2C(C1)C[N+]1(C)CCCCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C(C)CC(C[N+]12CCC)CCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1cc(C[N+]2(CCC(CCC2)CCCC2CC[N+](CC3)(C)Cc2ccccc2)C)ccc1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1(ccccc1)C[N+]1(CCC(CCCCCC2CC[N+](Cc3ccccc4)(C)CC2)CC1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CCCC[N+]2(CCCCC2)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1(C[N+]2(CCCCCC[N+]3(CCCCC3)C)C)ccccc1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1ccc(C[N+]2(CCC(CCCCCC3CC[N+](C2)(C)Cc3ccccc3)CC2)C)cc1'
# [13:22:05] SMILES Parse Error: syntax error while parsing: C1[N+]2(CCCCCCCC[N+]34CC(N(CC4)CC3)C)CCN(C(1)C)CC2
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1[N+]2(CCCCCCCC[N+]34CC(N(CC4)CC3)C)CCN(C(1)C)CC2' for input: 'C1[N+]2(CCCCCCCC[N+]34CC(N(CC4)CC3)C)CCN(C(1)C)CC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C(CCCC2CC[N+](CC2)(C)CC(O)CC2)CC[N+](CC(CC)C)(C1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC[N+](CC)(CC)CCC2C1C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+](CC2C3C4C(C[N+](CC)(C4)C(C)C)C2C=1)(CCC)CCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC2C(CC[N+](CC)(CC)CC)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2C(CC1)CCC[N+](CC)(CC)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C(CC[N+]2(C)C1)C[N+]1(C)CCCCC1'
# [13:22:05] SMILES Parse Error: syntax error while parsing: c1ccc(cc1)C[N+]1(C)CCC(CC1)CCCC1CC<unk>
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'c1ccc(cc1)C[N+]1(C)CCC(CC1)CCCC1CC<unk>' for input: 'c1ccc(cc1)C[N+]1(C)CCC(CC1)CCCC1CC<unk>'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCC1[N+]1(CCC(CCCC2)C1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CN2C(C)C[N+]1(CCCCCC[N+]13C(CN(C(C)C3)CC4)CC1C)CC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(CCCC2CC[N+](CC(C)CC)(C)CC2CC[N+](C)(CCCCCCC)CC2)CCCCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(CCCCCC[N+]34C(CN(CC4)C(C)C4)C)CCN1CC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1([N+]2(CCCCCCCC[N+]34C(N(CC3)CC4)C)C)CCCCC1C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+](CC)(CCCCCC[N+]2(CCCCC2)CCCC2)CCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C[N+]1(C)CCCCC1CC1CC1CCCC[N+]1(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CCCC[N+]3(C(C3CC[N+](C)(C)CC4CC3)C2)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](C)(CCC(C[N+](CC2)(C)C)C1)CC1CCC2CC1C2(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(C)(C)C2CC(CC3CCCC[N+]3(C)C1)[N+]1(C)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C(C(CCC2)C[N+]1(C)C)CC1CC[N+](C)(C)CC2CC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC2CC3C4C[N+](C)(C)CC4CCCC[N+]4(C)CC13'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CCCCC2[N+]1(C)C1CC3[N+](C)(CCCC3)CC1CC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CCCC[N+]3(CC)C(CC3[N+]2(C)CCCCC2C3)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC(CC(C)(C2(C)C)C1)C[N+](CC)(CC)C2(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCC2[N+]1(C)CC1CC2CCCC[N+]12C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1c(cccc1)C[N+]1(C)CCC(CC1)CC[N+](CC1)(Cc1ccccc1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C3C(CC4CCCC[N+]4(C)C3)CC1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC([N+]3(C)CCCCC3)CC3CC2[N+]2(C)CCCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2CC([N+]3(CCCC3)CCCC3)[N+]2(C)C1CCCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2CCCC[N+]2(C2CC3CCCC[N+]3C2C1CC3)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(CCCCC1)[N+]1(CCC(CCCCCC2)C1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1cc(CC2[N+](CCC(CCCC3CC[N+](Cc3ccccc3)(CC3)C)CC2)C1)ccccc1'
# [13:22:05] SMILES Parse Error: syntax error while parsing: C1[N+]2(CCC(CCCC1CC[N+](CC2)(C)Cc1ccc(C<unk>)cc1)C)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1[N+]2(CCC(CCCC1CC[N+](CC2)(C)Cc1ccc(C<unk>)cc1)C)C' for input: 'C1[N+]2(CCC(CCCC1CC[N+](CC2)(C)Cc1ccc(C<unk>)cc1)C)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 6 7 8 9 11 12 13 14 15 16 17
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 11 12 21
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 12 13 14 17 18 19 20 21 22 23
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 8 9 16 17 18 21 22 23 24
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(c1)C[N+]1(C)CCC(CCCC3CC[N+](C)(CC3)Cc3cc1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC[N+](CC2)(C)CCC1CCCC1CC[N+](CC2)(C)CC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1cc2C[N+]3(CCC(CCCC4CC[N+](CC3)(C)Cc4c1cc2)C=C2)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 3 4 11 12 13 23 24 25 26
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2CC[N+]1(CCCCCC[N+]1(CCC(CCCC2CC[N+](CC2)(C)CCCCC1)C)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2CC[N+](CC2)(C)Cc2ccc(cc2)C[N+]2(C)CC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CCCC3CC[N+](C)(Cc3ccc(cc3)C[N+](CCC2)(C)C)CC1C2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC2CCCC3CC[N+](CC3)(C)Cc3ccc(C1)cc3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c12[n+]3ccncc3ccc2ccc(Cn3cc[n+](c3)C1)c1ccc(cc2)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+](C)(CCC1CCCC1CC[N+](CC1)(C)Cc1ccc(C2)cc1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC[N+](CC2)(CCCCCC[N+]2(C)CCC(CC2)CCC2)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC[N+](CCCCCC[N+]3(C)CCC(CC3)CC4)(C)C1CC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1cn(CCCCCC[n+]2ccn(c2)Cc2ccc(cc2)C[n+]2ccn(C2)c2)cc1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1ccc2Cn3cc[n+]4c1CCC(CC3)CCCC4'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c1[n+](cn(CCCCCC[n+]2cn(CCCC)c3)c1)CCCC'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 19 20 21 22 24
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C)CCC(CCCC3CC[N+](C(CC)C4)(C1)C)CC2'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 9 10 19
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CCCC3CC[N+](C)(CCCCCC[N+](C1)(C)CC2)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 11 12 17
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 15 16 25
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C1CCCCN2)CC[N+](C)(CC1)CCCCCCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2CC[N+](CCCCCC[N+]3(C)CCC(CC3)CC4)(C1)CC2'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 9 10 11 12 19 20 21 23
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC[N+](CC2)(C1)CCC(C)CCCC1CC[N+](CC1)(C)Cc1ccc(cc1)C[N+](C)(CC2)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC[N+](CCCCCC[N+]3(C)CCC(CC3)CC4)(C1)CC2'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 18 19 28
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C(C3C=CC2C2C3C[N+](C(C)C)(CC)CC3)C[N+]1(CCC)C(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C(C3C4C[N+](CC4C(C=C3)C23)(C(C)C)CC)C1'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C12CC[N+](C(C)C)(CC1)C(C)C)CC2
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C12CC[N+](C(C)C)(CC1)C(C)C)CC2' for input: 'C12CC[N+](C(C)C)(CC1)C(C)C)CC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC4C(C3C1C[N+](CC)(C(C)C)CC)(CC)C2C=C3)(CCC)C(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C=CC(C3C[N+](CC32C1C1C3C[N+](C(C)C)(C4)CC1)CCC)C2'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C(C)C[N+]1(C)CCCCC1)CCCCCC(C)[N+]1(CCCCC1)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C(C)C[N+]1(C)CCCCC1)CCCCCC(C)[N+]1(CCCCC1)C' for input: 'C(C)C[N+]1(C)CCCCC1)CCCCCC(C)[N+]1(CCCCC1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C3C=CC(C4C[N+](CC43)(CCC)C(C)C)C2C[N+](CC12)(CCC)C(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2(C3C4C[N+](CC4C(C=C3)C3)(C(C)C)CCC)CC[N+]1(C(C)C)CCC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C(C3C4C[N+](CC3C(C=C4)C23)(C(C)C)CCC)C[N+](C1)(CCC)CC'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 1 2 10 12 13
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12(CC3CC(CC(C3)C2CC3)[N+](C)(C)C)CCCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CC([N+](C)(C)C)C(C1)C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[N+](C)(C)(C1C2CC3CC(C2)C1)CCC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C1)CC([N+](C)(C)C)C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC4CC1C3)[N+](C)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(C1)C([N+](C)(C)C)C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+](CC2C3C4C(C[N+](C)(C5)C)C(C=1)C23)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1C3)C[N+](C)(C)C[N+](C)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[N+](C)(C1C2CC3CC(C3)C1)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CC([N+](C)(C)C)C(C1)C3'
# [13:22:05] Explicit valence for atom # 5 C, 5, is greater than permitted
# [13:22:05] Explicit valence for atom # 6 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(C)CCCC3(C2CCCCN2C1)CCCC3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12[N+](CC3CC(C2)CC(C3)C1)(C)CCCC[N+]1(C)C2CCCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(CCCCCCCCC)CCCCCCC[N+](C)(C)CCCC[N+](C)(C12CC3CC(CC(C3)C3)C1)C2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(CC(C3)(C)C1)[N+](C)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12[N+](CCCC[N+]3(C)C4CCC(C3)C4)(CC3CCC1CCC2)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2[N+](CCCC[N+]3(C)C4CCC(CC5)C3)(C(C1)CC2)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+](C1)(CC)C1CC(C2(C)C)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CCCC[N+]2(CC)CCCC1C2(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C(C)(C)C(C([N+](C)(CC)C1)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3(C)CC(C1)CC(C3CCCC[N+]13C)C2'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C12C)[N+](C)(C)CCCC1C2
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C12C)[N+](C)(C)CCCC1C2' for input: 'C12C)[N+](C)(C)CCCC1C2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1([N+]2(CCCCCC[N+]2(CCCCC2)C)CCCC1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+](C)(C)CC2(OCC1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C[N+]1(Cc1ccccc1)C)C[N+]1(CCCCC1)C'
# [13:22:05] SMILES Parse Error: syntax error while parsing: C1(CO)N+](C)(CCC1)Cc1ccccc1
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1(CO)N+](C)(CCC1)Cc1ccccc1' for input: 'C1(CO)N+](C)(CCC1)Cc1ccccc1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCC([N+]1(C)C)CC2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+](C)(C)CCC1CCCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC2CCCCC12C[N+](C)(C)C2'
# [13:22:05] Explicit valence for atom # 3 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C(C)(C)C[N+]1(CCCC(C)(C)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(CC[N+]1(C)CC2)CCCC2'
# [13:22:05] Explicit valence for atom # 2 N, 4, is greater than permitted
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 14 15 16 17
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 2 3 6
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 14 15
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 2 13 14 15
# [13:22:05] SMILES Parse Error: syntax error while parsing: Cn1c[n+](cc1)CCCCC[n+]1n+](C)ccc1
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'Cn1c[n+](cc1)CCCCC[n+]1n+](C)ccc1' for input: 'Cn1c[n+](cc1)CCCCC[n+]1n+](C)ccc1'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 14 15
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 2 13 14 15 16
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 5 6 8 9 10
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 4 5 6
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 15 17 18 19 20
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 3 4 5
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(C)c3c(C1)ccc3'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 2 6 7 8
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[n+]1(CCCCC[n+]1n(cc(c1C)C)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'n1(C)c(C)[n+](CCCC[n+]1c(C)n(cc1)C)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 7
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C[N+]1(CCC(C)C2C(C)(C)C(C1C)C)C'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C1C(C)(C)C2(C)CC(C1(C2)[N+](C)(C)C)C)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1C(C)(C)C2(C)CC(C1(C2)[N+](C)(C)C)C)C' for input: 'C1C(C)(C)C2(C)CC(C1(C2)[N+](C)(C)C)C)C'
# [13:22:05] Explicit valence for atom # 2 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12(n3cc[n+](C45C6CC(C(C4)CC(C4)C4)C)c3)CC3CC(C1)CC(C2)C3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(C2N(C)CCC1)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC(C2(C)C)C(CC1)C[N+](C)(C)C2'
# [13:22:05] SMILES Parse Error: ring closure 2 duplicates bond between atom 1 and atom 14 for input: 'C1C2(C)(CC(C)(C)CC(C1)[N+](C)(C)C)C2'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 2 5 7 9 10
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 15 17 19
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 2 14 15 16
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+](C1CCCC2C1C)(C)C'
# [13:22:05] Explicit valence for atom # 0 C, 5, is greater than permitted
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC1CC(C2C(C)C)(C)[N+](CC1)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2C([N+](C)(CCCC[N+](C2)(C)C)C)C1CC2CCC1'
# [13:22:05] Explicit valence for atom # 3 C, 5, is greater than permitted
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 4 5
# [13:22:05] Explicit valence for atom # 0 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 8 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 7 N, 4, is greater than permitted
# [13:22:05] Explicit valence for atom # 3 C, 5, is greater than permitted
# [13:22:05] Explicit valence for atom # 6 C, 5, is greater than permitted
# [13:22:05] Explicit valence for atom # 1 N, 4, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12C[N+](C)(C)C(CC2)C2CCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC(C(CC[N+]1(CC)C)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12(C)C(CCC(C)C[N+](C)(C)C1C)C'
# [13:22:05] Explicit valence for atom # 7 C, 5, is greater than permitted
# [13:22:05] Explicit valence for atom # 2 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC1(C)C2CC(C)CC[N+]1(C)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12(CC([N+](C)(C)C)CC(C2(C)C)C)C'
# [13:22:05] Explicit valence for atom # 3 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CCCCC[N+](C)(C2CCCCC21)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+](C1C2CC(C)C1(C)CC2)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2C(CCC1)[N+](C)(C)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(C)(C)C2(C)CCC([N+](C)(C1)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCC2C3CC(C12C[N+](C)(C3)C)C2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCC23CCCC[N+]3(CC1)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCC2CCCCC2C[N+](C)(C)C12'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2[N+](C)(C1CC1C2(C)C)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC2C(C1)C(C2C[N+]1(C)CC)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC(C2C(C)(C)C2C1C)C[N+](CC)(CC)C2'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2C(C(C1C)C)[N+](C)(C)C'
# [13:22:05] SMILES Parse Error: syntax error while parsing: C1CC(C2CC((C)C1C)C2(C)C)[N+](C)(C)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1CC(C2CC((C)C1C)C2(C)C)[N+](C)(C)C' for input: 'C1CC(C2CC((C)C1C)C2(C)C)[N+](C)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+](C)(C)C1C2(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+](C)(C)C(C)(C)C2C(C1C)(C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[N+](C)(C)(C)C1CC(C2(C)C)C1C'
# [13:22:05] SMILES Parse Error: extra close parentheses while parsing: C1[N+](C)(C)CCC(C)C1C2(C)C)C
# [13:22:05] SMILES Parse Error: Failed parsing SMILES 'C1[N+](C)(C)CCC(C)C1C2(C)C)C' for input: 'C1[N+](C)(C)CCC(C)C1C2(C)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'CC1(C2CC(C1C2)[N+](CC1)(CC)C)C'
# [13:22:05] Explicit valence for atom # 4 C, 5, is greater than permitted
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2(C)CC(C([N+](C1)(C)C)(C)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1(CC[N+](C)(C)CC1C2(C)C)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC(C[N+]1(C)C)(CC)C'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1CC[N+](C)(C1CC[N+](C)(C)CC1)C'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 10 12 13 14 15
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 11 13 14 15
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 2 11 13 15 16
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5 6 9 10 12 13 14 15 16
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(CCCc3cccc1c2)CC'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1c2cccc3CCC[N+]1(c1ccc3)C1CC'
# [13:22:05] Can't kekulize mol.  Unkekulized atoms: 0 1 2 8 9 10 11
# [13:22:05] SMILES Parse Error: unclosed ring for input: '[N+]12(C)CCCc3c(CC1)cccc3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C12CC3CCC([N+](C)(C)C)(C3)C1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'c12c3CCC[N+]13CCCC3'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1NCCN(CCN)C1CCNCC1'
# [13:22:05] SMILES Parse Error: unclosed ring for input: 'C1C2CC(C[N+]1(C)C)(C)C'
# ...
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C123C4CCCC(C3)(C[N+](C2)(C)C)CCC1'
# [13:23:09] Explicit valence for atom # 3 C, 5, is greater than permitted
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C[N+]1(C)CC23C(C(C3)(C=C1)CC2)CCCC[N+](C)(C)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C23C4C(C(C=C3)C1)C[N+](C)(C)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C23CCCCC3(C2)C=1C[N+](C2)(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C123C4CCCC4(C3CC4CCC4)C[N+](C1)(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(C2)C[N+]1(CC)CC'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C123CCCCC2(C=C3)C2(C[N+](C)(C)C3)C1C4C[N+](C)(C2)C'
# [13:23:09] SMILES Parse Error: duplicated ring closure 4 bonds atom 1 to itself for input: 'C123C44CC(C=C4)(C[N+](C)(C4)C)C3(C=C1)C[N+](C)(C2)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(CC(CCC3)(C1)C)[N+](C)(C)C'
# [13:23:09] SMILES Parse Error: extra close parentheses while parsing: Cn1[n+](C)ccc1C)C(C)C
# [13:23:09] SMILES Parse Error: Failed parsing SMILES 'Cn1[n+](C)ccc1C)C(C)C' for input: 'Cn1[n+](C)ccc1C)C(C)C'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC(C)(C)CC(C)(C)[N+](C)(C)C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: '[N+]12(CCCCC2)CCCC(C)(C2)C'
# [13:23:09] Explicit valence for atom # 1 C, 5, is greater than permitted
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC(C[N+]3(C)C)C2)C1C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC(C)(C)C2(C)C[N+]1(CC)CC'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 2 16 18 19
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C(C)(C)C2(CC1[N+](C)(C)C)C'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 17 18 19
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 2 3 4 11 12 14 15 19
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c1(C)c(C)[n+](CCCCC[n+]2c(n(c(c3C)C)C)C)c(n1C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2C[N+](C)(C3CCC(C3)C1C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(CC(C3)C1)(C)[N+](C)(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CCC3CCC(C1C3)[N+](CC)(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3CC([N+](C)(C)C)C(C1)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12C[N+](C)(CC(C3)CCC1C3)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1CC(C3)(n1cc[n+](C1C34CC(CC(C3)C2)C4)c1)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2C3CCC(C(C[N+]1(C)C)C)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12C(C)(C)C(C)C(CC1)[N+](C)(C)C'
# [13:23:09] SMILES Parse Error: extra close parentheses while parsing: C1CC2C)[N+](CC)(CC1CC2)C
# [13:23:09] SMILES Parse Error: Failed parsing SMILES 'C1CC2C)[N+](CC)(CC1CC2)C' for input: 'C1CC2C)[N+](CC)(CC1CC2)C'
# [13:23:09] Explicit valence for atom # 7 C, 5, is greater than permitted
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2C34CCCCC3(CC(C3)C1)C[N+](C)(C2)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1[N+](C)(CC)C)C2'
# [13:23:09] Explicit valence for atom # 6 C, 5, is greater than permitted
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(C2)[N+](CC)(C1)CC'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC2CC3CC(CC4C[N+]31C)CC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(CC(C3)CC(C1)C2)[N+]3(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CCC(C3CCC3C[N+]3(C)C)C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1CC(C2)(C3)C[N+](C)(C)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12C[N+](CC)(C)CC(C1)C1CC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(C2)C[N+]1(C)CC'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C[N+](C)(C)C)(C2)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1C3)[N+](C)(C)CC(C3)C2'
# [13:23:09] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC23CCCC[N+]2(CC1)CCCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(n4cc[n+](c4)C45CC6CC(C5)CC(C5)C5)(CC(C3)C2)C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1CC([N+](C)(C)C)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CCC(C3)C[N+]1(C)CC(C2)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC2C3CCC(C3)C[N+]1(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CCC(C(C[N+](C)(C2)C)C1)O3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC2CC[N+](Cc3c2cccc3)(C)C1CCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC(CC2)C2C[N+](C)(C1C1CCC2)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12C3CC(C(CC2)[N+](C)(C)C)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC2C3CCC(C([N+]1(C)C)C)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(C2)C[N+]1(C)CC'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC2C3CCC(C[N+]1(C)C)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC2C3CC(C)(C)C(C[N+]1(C)C)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12[N+](CCCCC2CCC1C2)(C)C'
# [13:23:09] SMILES Parse Error: ring closure 2 duplicates bond between atom 3 and atom 4 for input: 'C1CCC2C2CCC[N+](C1C2)(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CCC(C3OC3)[N+](C)(C)CC1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3CC([n+]4cn(cc4)C45CC6CC(CC(C4)C6)C5)C2C=C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2[N+](C)(CC3CC(C1C2)C)(C)CC'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CCCC[N+](C)(C2C(C)(C)C1C2)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3(n4c[n+](cc4)C45CC6CC(CC(C6)C5)C5)CC(C1)CC(C3)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C[N+]1(C)CC2C3CC3CC(C3)CC1C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2C[N+](C(C1)C1CCC2C3)(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(CC(CC(C[N+]31C)C)C2)C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC([N+](C)(C)C)C1C3'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3C[N+](C(C1)CC1CC3)(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC2C3CCC(C3)C[N+]1(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC(C)(CC2(C)C[N+]1(C)C)C'
# [13:23:09] SMILES Parse Error: extra close parentheses while parsing: C12CC(C)(C)CC(C1)(C)C)C[N+]2(C)C
# [13:23:09] SMILES Parse Error: Failed parsing SMILES 'C12CC(C)(C)CC(C1)(C)C)C[N+]2(C)C' for input: 'C12CC(C)(C)CC(C1)(C)C)C[N+]2(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3(CC(CC(C3)C1)C2)n1c(C2)cc[n+]1C(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC(C)(C)CC(C)(C)C1[N+](C)(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(CC(C1)(C3)n1c[n+](C34CC5CC(C3)CC(C4)C4)cc1)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C(C)(C)CC2(C[N+](C)(C1)C)C'
# [13:23:09] SMILES Parse Error: extra close parentheses while parsing: C1C2(C)CC(C)(C)CC(C)(C2)C)C[N+]1(C)C
# [13:23:09] SMILES Parse Error: Failed parsing SMILES 'C1C2(C)CC(C)(C)CC(C)(C2)C)C[N+]1(C)C' for input: 'C1C2(C)CC(C)(C)CC(C)(C2)C)C[N+]1(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC2C(CCC[N+]32CCCCC2C)C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCCC[N+]12C(CCC[N+]1(C)C2CCC1CCC2)C'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 15 19
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 13 15 16
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 3 4 17
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 3 4 5
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 14 15 19 20 21
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 6
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 6
# [13:23:09] non-ring atom 2 marked aromatic
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 8 9 11 12 13
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 15 18 19
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 6 7
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 1 2 3 17 20
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1C3)(n1c[n+](C45CC6CC(C5)CC(C4)C4)cc1)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CCCC3CCCC(C32CCCCC32)C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1[N+](C)(CC2C3C4C(C[N+](C)(C)C5)C(C=C3)C21)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12C3C(CCCC3C2CCC1)CCCCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2C3C[N+]4(C)CCCCC4C(C3)C=1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2C3C(C1)CCCC3CCCCC2CCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12C(C3C=CC2C2C[N+](CC32)(CC)CC)C[N+](CC12)(CC)C'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 2 3 6 7 8 9 10 17 18 25
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2C=CC(C3C[N+]4(C)CCCCC4C3)C2C1C[N+](C)(C)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: '[N+]12(Cc3ccccc3)CCc3ccccc3C1'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 13 15 16
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 3 4 20 21
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC[N+](C)(C)CCCCC[N+]2(C)CCCCC2'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 10 11 12 13 14
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 11 13 14 15
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c12ccccc1C[n+]1ccn(c1)CCC'
# [13:23:09] SMILES Parse Error: syntax error while parsing: C1NH3CCN1CCCCC2
# [13:23:09] SMILES Parse Error: Failed parsing SMILES 'C1NH3CCN1CCCCC2' for input: 'C1NH3CCN1CCCCC2'
# [13:23:09] SMILES Parse Error: syntax error while parsing: C1(C)CNHC(CC1)N
# [13:23:09] SMILES Parse Error: Failed parsing SMILES 'C1(C)CNHC(CC1)N' for input: 'C1(C)CNHC(CC1)N'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 7 8
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 4 5 6 9 10 12 13 14 15 16 17
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c1cc2cccc3c1c(C[N+]1(C2)CCCCC1)C'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 11 12 13 14
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(CCCC3C(CC2)C)CCCC1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+]2(CC1)CC1C(C)CCC1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2(C)CC(CC([N+]3(CCCC2)CC)C1)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC([N+]2(CCCC2)CCCCC2)CC1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c1cc2c(C[N+]3(C2)CCCCC3)cc1C[N+]1(CCCC(C)C1)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c12ccccc2[N+]1(C[N+]1(CCCCC1)CC2)CC'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C(C)(C)CC2CC1(C)C[N+]12CCCCC21'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2CC[N+]21CCCC2C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C(C)CCC2)CCCCC2C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1(C)C[N+]2(C(CCC1)C)CCCC[N+]12CC(C)N(CC1)CC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c12ccccc2C[N+]1(C(CCCC1C)C)C2'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 15 16 17 18
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(CCCC2)CC([N+]2(CCCC2)CC(C)C2)C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c12ccccc2C[N+]2(CCCCC2C1)C2C'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 14
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+]2(CCCC12)CCCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: '[N+]12(CCCCC3C(C[N+]3(CC2)CCCCC3)C)CCCCC1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(CCCC3(C)C)C1C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(Cc3c(C[N+]4(CC(C)C)CC3)cccc3)CCCC1CC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC2C[N+]3(CCCCC3)C(C)C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCCC[N+]12CC1(CC2CC2C1)(C)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: '[N+]12(CCC(CC2)CC1)CCCCC2C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCCC2CCC[N+]3(C1)CCCC3C'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 6 7 8 9
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c1cccc2c1C[N+]1(CCCCC2CCC1)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: '[N+]12(CCCCC1)CCCC2CCCCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC(C)C[N+]2(C1)CCCCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1c2c(cccc1)C[N+]1(CCCCC2CCC1)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC2C(CC1)CC[N+]12CCCCC2C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c1c2c(C[N+]3(CCCCC2)C1)cccc1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(CC1)C(Cc1ccccc1)C[N+]12CCC(CC1)CC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C(CCC[N+]12CC(C)C)[N+]1(CCCCC1)CCC'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(C[N+]3(Cc1cccc3)CC(C)CCC3)CC(CCC2)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1(C)CCC[N+]2(Cc3c(C[N+]4(C2)CC(C)C4)CCCC(C5)C)ccc1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(C(CC)C)CCCCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(CCCC2)CC(CCC2)C1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCCCC1[N+]1(Cc3c(C1)cccc3)CCCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: '[N+]12(CCCCC2C1)CCCCC2CC'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(CCC1)CC1(C)CCCCC1'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 0 1 2 16 17 18 19 20 21
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(CCCCC3CC)CCCCC21'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'CC1CCCCC1[N+]1(Cc3c(cccc3)C1)C1CCCC[N+]1(C2)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c1ccc2C[N+]3(CCCC(C)C3)Cc1cc1cccc1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1(C)CC(C[N+]2(CC[N+]3(CC2)CC(CC(C)C2)C)C1)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c1ccc2C[N+]3(C[N+]3(Cc4ccccc4)C(CCCC4)CC2)Cc1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c12c(C[N+]3(C1)CCCCC2C)cccc2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c1cc(C[N+]2(C[N+]3(CCCC(C3)C)CCCC2C)CCCC(C)C1)cccc1'
# [13:23:09] SMILES Parse Error: ring closure 2 duplicates bond between atom 9 and atom 10 for input: 'c1cc(ccc1)C[N+]1(C[N+]2(C2)CCCC(C)C2)CCCC(C1)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'c12c3C[N+]3(C(CCCC3)Cc2)Cc2cccc1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CCCC[N+]3(CC1)CC1CCCCC12'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCCC2[N+]13CCCC1(C)CCCC2C3'
# [13:23:09] Can't kekulize mol.  Unkekulized atoms: 7 8 9 17 18
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1CCC2[N+](C1)(C1CC3C=C1)CCCCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C2CC3C(CC(C4[N+](C)(C)C)C2C3)C=1'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(CC4[N+]3(C)CCCCC4C3)C1CC2CCC2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C12CC3[N+]4(C)CCCCC4C(C1)CC([N+]1(C)CN(CC1C)C)C2'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1C(N2CC[N+]1(CCCC2)C)CCCC[N+]12CCN(CC1)C'
# [13:23:09] SMILES Parse Error: unclosed ring for input: 'C1(CC2CC(CC)[N+]1(C)C)O'
# FCD score: 0.22891701777976792

# %%
# plot the loss and acc
plot_loss(train_loss_history, test_loss_history, 'Clamer_contrastive_loss')

# %%
# save the history to the csv file in log folder
history = pd.DataFrame({'train_loss': train_loss_history, 'train_acc': train_acc_history, 'test_loss': test_loss_history, 'test_acc': test_acc_history, 'train_ce_loss': train_ce_loss_history, 'test_ce_loss': test_ce_loss_history, 'train_info_loss': train_info_loss_history, 'test_info_loss': test_info_loss_history})
history.to_csv(log_dir + 'clamer_contrastive_history.csv', index=False)
