# %% [markdown]
# # Train Clamer Model with Pre-setting Vocab

# %%
# change to the directory of the script
# %cd ..
# Out:
# /home/hudongcheng/Desktop/bo_osda_generator

# %%
import numpy as np
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.nn import functional as F
from tqdm import tqdm
from datetime import datetime
from torch.utils.tensorboard import SummaryWriter
import torch.backends.cudnn as cudnn

# import custom modules
from datasets.data_loader import *
from models.clamer import *
from models.loss import InfoNCELoss
from models.trfm import *
from utils.utils import *
from utils.plot_figures import *
from utils.metrics import *
from utils.build_vocab import *

# %%
cudnn.benchmark = True
cudnn.enabled = True

train_loss_history = []
train_acc_history = []
test_loss_history = []
test_acc_history = []
train_ce_loss_history = []
test_ce_loss_history = []
train_info_loss_history = []
test_info_loss_history = []

log_dir = './logs/'
save_best_weight_path = './checkpoints/'

now = datetime.now().strftime('%Y-%m-%d-%H-%M-%S')

# %%
PAD = 0
UNK = 1
EOS = 2
SOS = 3
MASK = 4
MAX_LEN = 220

# %%
# read the data from the file
train_data = pd.read_csv('./data/train_contrastive_dataset.csv')
test_data = pd.read_csv('./data/test_contrastive_dataset.csv')

vocab = WordVocab.load_vocab('./model_hub/vocab.pkl')
print('the vocab size is :', len(vocab))

charlen = len(vocab)
print('the total num of charset is :', charlen)
# Out:
# the vocab size is : 45
# the total num of charset is : 45

# %%
# hyperparameters
d_model = 128
head = 4
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
batch_size = 64
epoch = 10

# %%
# create the dataset and dataloader
# train_dataset = Contrastive_Seq2seqDataset(train_data, vocab, MAX_LEN)
# test_dataset = Contrastive_Seq2seqDataset(test_data, vocab, MAX_LEN)
train_dataset = Contrastive_Seq2seqDataset_random(train_data, vocab, MAX_LEN)
test_dataset = Contrastive_Seq2seqDataset_random(test_data, vocab, MAX_LEN)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# load model
model = GptCovd(d_model=d_model, charlen=charlen, device=device, head=head).to(device, non_blocking=True)

# load model
trfm = TrfmSeq2seq(charlen, 256, charlen, 4).to(device)
trfm.load_state_dict(torch.load('./model_hub/trfm_new_2_10000.pkl'))
trfm.eval()

# set trfm gradient to false which won't be updated
for param in trfm.parameters():
    param.requires_grad = False

# loss
loss_func = torch.nn.CrossEntropyLoss(ignore_index=PAD)
optim = torch.optim.Adam(model.parameters(), lr=6e-4)
total = sum(p.numel() for p in model.parameters())
print('total parameters: %0.2fM' % (total / 1e6))
# Out:
# 100%|██████████| 144938/144938 [00:00<00:00, 878661.17it/s]
# 100%|██████████| 144938/144938 [00:00<00:00, 795267.01it/s]
# 100%|██████████| 144938/144938 [00:02<00:00, 51707.77it/s]
# 100%|██████████| 14803/14803 [00:00<00:00, 1660958.30it/s]
# 100%|██████████| 14803/14803 [00:00<00:00, 1069105.16it/s]
# 100%|██████████| 14803/14803 [00:00<00:00, 52069.92it/s]
# total parameters: 1.34M

# %%
# train function
def train(model, trfm, train_dataloader, loss_func, optim, device, weight=0.1):
    model.train()
    total_loss = 0
    total_loss_crossentropy = 0
    total_loss_infonce = 0
    total_acc = 0
    total_num = 0
    for i, (zeo, syn, tgt, positive_smiles, negative_smiles) in enumerate(tqdm(train_dataloader)):
        zeo = zeo.to(device)
        syn = syn.to(device)
        tgt = tgt.to(device)
        positive_smiles = positive_smiles.to(device)
        negative_smiles = negative_smiles.to(device)
        
        tgt_input = tgt[:, :-1].contiguous()
        tgt_label = tgt[:, 1:].contiguous()
        
        # forward
        optim.zero_grad()
        # ignore the first two tokens becauese thay are condition tokens
        output = model(zeo, syn, tgt_input)
        logits = output[:, 2:, :].to(device, non_blocking=True).contiguous()
        
        # Compute CrossEntropy Loss
        logits_reshaped = logits.view(-1, logits.size(-1))
        tgt_label_reshaped = tgt_label.view(-1)
        loss_ce = loss_func(logits_reshaped, tgt_label_reshaped)
        
        # calculate the accuracy
        pred = torch.argmax(logits, dim=-1)
        num_correct = (pred == tgt_label) & (tgt_label != PAD)
        num_words = (tgt_label != PAD).sum().item()
        
        # Gumbel-Softmax Sampling
        # logits: [batch_size, seq_len, vocab_size]
        samples = F.gumbel_softmax(logits, tau=1.0, hard=True)
        samples_indices = samples.argmax(dim=-1) # [batch_size, seq_len]
        # add the start token to the samples
        stared_token = torch.ones(samples_indices.size(0), 1, dtype=torch.long).fill_(SOS).to(device)
        samples_indices = torch.cat([stared_token, samples_indices], dim=-1)
        
        # Compute InfoNCE Loss
        loss_infonce = InfoNCELoss(samples_indices, positive_smiles, negative_smiles, trfm, temperature=0.07)
        
        # combine the two loss
        loss = loss_ce + weight * loss_infonce
        
        # backward
        loss.backward()
        optim.step()
        
        # statistics
        total_loss += loss.item()
        total_loss_crossentropy += loss_ce.item()
        total_loss_infonce += loss_infonce.item()
        total_acc += num_correct.sum().item()
        total_num += num_words
    return total_loss / len(train_dataloader), total_acc / total_num, total_loss_crossentropy / len(train_dataloader), total_loss_infonce / len(train_dataloader)

# %%
def evaluate(model, trfm, test_dataloader, loss_func, device, weight=0.1):
    model.eval()
    total_loss = 0
    total_loss_crossentropy = 0
    total_loss_infonce = 0
    total_acc = 0
    total_num = 0
    with torch.no_grad():
        for i, (zeo, syn, tgt, positive_smiles, negative_smiles) in enumerate(tqdm(test_dataloader)):
            zeo = zeo.to(device)
            syn = syn.to(device)
            tgt = tgt.to(device)
            positive_smiles = positive_smiles.to(device)
            negative_smiles = negative_smiles.to(device)
            
            tgt_input = tgt[:, :-1].contiguous()
            tgt_label = tgt[:, 1:].contiguous()
            
            # forward
            # ignore the first two tokens becauese thay are condition tokens
            output = model(zeo, syn, tgt_input)
            logits = output[:, 2:, :].to(device, non_blocking=True).contiguous()
            
            # Compute CrossEntropy Loss
            logits_reshaped = logits.view(-1, logits.size(-1))
            tgt_label_reshaped = tgt_label.view(-1)
            loss_ce = loss_func(logits_reshaped, tgt_label_reshaped)
            
            # calculate the accuracy
            pred = torch.argmax(logits, dim=-1)
            num_correct = (pred == tgt_label) & (tgt_label != PAD)
            num_words = (tgt_label != PAD).sum().item()
            
            # Gumbel-Softmax Sampling
            # logits: [batch_size, seq_len, vocab_size]
            samples = F.gumbel_softmax(logits, tau=1.0, hard=True)
            samples_indices = samples.argmax(dim=-1) # [batch_size, seq_len]
            # add the start token to the samples
            stared_token = torch.ones(samples_indices.size(0), 1, dtype=torch.long).fill_(SOS).to(device)
            samples_indices = torch.cat([stared_token, samples_indices], dim=-1)
            
            # Compute InfoNCE Loss
            loss_infonce = InfoNCELoss(samples_indices, positive_smiles, negative_smiles, trfm, temperature=0.07)
            
            # combine the two loss
            loss = loss_ce + loss_infonce
            
             # statistics
            total_loss += loss.item()
            total_loss_crossentropy += loss_ce.item()
            total_loss_infonce += loss_infonce.item()
            total_acc += num_correct.sum().item()
            total_num += num_words
    return total_loss / len(test_dataloader), total_acc / total_num, total_loss_crossentropy / len(test_dataloader), total_loss_infonce / len(test_dataloader)

# %%
# train the model
for i in range(epoch):
    train_loss, train_acc, train_ce, train_info = train(model, trfm, train_dataloader, loss_func, optim, device)
    # train_loss, train_acc, train_ce, train_info = train(model, trfm, test_dataloader, loss_func, optim, device)
    train_loss_history.append(train_loss)
    train_acc_history.append(train_acc)
    train_ce_loss_history.append(train_ce)
    train_info_loss_history.append(train_info)
    print('epoch: %d, train loss: %.4f, train acc: %.4f, train crossentropy loss: %.4f, train infonce loss: %.4f' % (i, train_loss, train_acc, train_ce, train_info))
    test_loss, test_acc, test_ce, test_info = evaluate(model, trfm, test_dataloader, loss_func, device)
    test_loss_history.append(test_loss)
    test_acc_history.append(test_acc)
    test_ce_loss_history.append(test_ce)
    test_info_loss_history.append(test_info)
    print('epoch: %d test loss: %.4f, test acc: %.4f, test crossentropy loss: %.4f, test infonce loss: %.4f' % (i, test_loss, test_acc, test_ce, test_info))
    if i == 0:
        best_acc = test_acc
    if test_acc > best_acc:
        best_acc = test_acc
        torch.save(model.state_dict(), save_best_weight_path + 'best_clamer_contrastive_model.pth')
    torch.save(model.state_dict(), save_best_weight_path + 'last_clamer_contrastive_model.pth')
    
    # save every epoch model to clamer folder
    torch.save(model.state_dict(), save_best_weight_path + '/clamer/clamer_contrastive_model_' + str(i) + '.pth')
# Out:
# 100%|██████████| 2265/2265 [19:17<00:00,  1.96it/s]
# epoch: 0, train loss: 1.2308, train acc: 0.7187, train crossentropy loss: 0.7880, train infonce loss: 4.4277
# 100%|██████████| 232/232 [01:54<00:00,  2.03it/s]
# epoch: 0 test loss: 4.9305, test acc: 0.7938, test crossentropy loss: 0.5515, test infonce loss: 4.3790
# 100%|██████████| 2265/2265 [19:18<00:00,  1.96it/s]
# epoch: 1, train loss: 0.9566, train acc: 0.8004, train crossentropy loss: 0.5161, train infonce loss: 4.4050
# 100%|██████████| 232/232 [01:53<00:00,  2.04it/s]
# epoch: 1 test loss: 4.8310, test acc: 0.8232, test crossentropy loss: 0.4603, test infonce loss: 4.3707
# 100%|██████████| 2265/2265 [19:17<00:00,  1.96it/s]
# epoch: 2, train loss: 0.8803, train acc: 0.8245, train crossentropy loss: 0.4409, train infonce loss: 4.3937
# 100%|██████████| 232/232 [01:53<00:00,  2.04it/s]
# epoch: 2 test loss: 4.7705, test acc: 0.8375, test crossentropy loss: 0.4142, test infonce loss: 4.3563
# 100%|██████████| 2265/2265 [19:18<00:00,  1.96it/s]
# epoch: 3, train loss: 0.8406, train acc: 0.8366, train crossentropy loss: 0.4016, train infonce loss: 4.3900
# 100%|██████████| 232/232 [01:53<00:00,  2.04it/s]
# epoch: 3 test loss: 4.7410, test acc: 0.8461, test crossentropy loss: 0.3865, test infonce loss: 4.3545
# 100%|██████████| 2265/2265 [19:18<00:00,  1.96it/s]
# epoch: 4, train loss: 0.8156, train acc: 0.8444, train crossentropy loss: 0.3768, train infonce loss: 4.3884
# 100%|██████████| 232/232 [01:53<00:00,  2.04it/s]
# epoch: 4 test loss: 4.7279, test acc: 0.8501, test crossentropy loss: 0.3729, test infonce loss: 4.3550
# 100%|██████████| 2265/2265 [19:17<00:00,  1.96it/s]
# epoch: 5, train loss: 0.7980, train acc: 0.8496, train crossentropy loss: 0.3592, train infonce loss: 4.3874
# 100%|██████████| 232/232 [01:53<00:00,  2.04it/s]
# epoch: 5 test loss: 4.7127, test acc: 0.8546, test crossentropy loss: 0.3584, test infonce loss: 4.3543
# 100%|██████████| 2265/2265 [19:17<00:00,  1.96it/s]
# epoch: 6, train loss: 0.7846, train acc: 0.8538, train crossentropy loss: 0.3459, train infonce loss: 4.3871
# 100%|██████████| 232/232 [01:53<00:00,  2.04it/s]
# epoch: 6 test loss: 4.6919, test acc: 0.8563, test crossentropy loss: 0.3483, test infonce loss: 4.3435
# 100%|██████████| 2265/2265 [19:17<00:00,  1.96it/s]
# epoch: 7, train loss: 0.7740, train acc: 0.8571, train crossentropy loss: 0.3352, train infonce loss: 4.3877
# 100%|██████████| 232/232 [01:53<00:00,  2.04it/s]
# epoch: 7 test loss: 4.6951, test acc: 0.8590, test crossentropy loss: 0.3402, test infonce loss: 4.3549
# 100%|██████████| 2265/2265 [19:18<00:00,  1.96it/s]
# epoch: 8, train loss: 0.7658, train acc: 0.8598, train crossentropy loss: 0.3267, train infonce loss: 4.3913
# 100%|██████████| 232/232 [01:53<00:00,  2.04it/s]
# epoch: 8 test loss: 4.6982, test acc: 0.8594, test crossentropy loss: 0.3357, test infonce loss: 4.3625
# 100%|██████████| 2265/2265 [19:18<00:00,  1.96it/s]
# epoch: 9, train loss: 0.7591, train acc: 0.8620, train crossentropy loss: 0.3193, train infonce loss: 4.3980
# 100%|██████████| 232/232 [01:53<00:00,  2.04it/s]
# epoch: 9 test loss: 4.7005, test acc: 0.8615, test crossentropy loss: 0.3292, test infonce loss: 4.3713

# %%
# # load the last model
# model = GptCovd(d_model=d_model, charlen=charlen, device=device, head=head).to(device, non_blocking=True)
# model.load_state_dict(torch.load('./checkpoints/clamer/clamer_contrastive_model_9.pth'))

# %%
def generate_clamer(model, start_sequence, zeo, syn, max_length, vocab, device, temperature=1.0, top_k=0):
    """
    Autoregressive generation process for a GPT model.

    Args:
        model (CLAMER): The pre-trained GPT model for token generation.
        start_sequence (torch.Tensor): The initial sequence to start generation (batch_size, seq_length).
        zeo (torch.Tensor): The zeolite condition tensor.
        syn (torch.Tensor): The synthesis condition tensor.
        max_length (int): The maximum length of the generated sequence.
        vocab: The vocabulary object for encoding and decoding SMILES strings.
        device (torch.device): The device on which to run the generation.
        temperature (float): Temperature parameter for sampling; higher values increase randomness.
        top_k (int): Limits sampling to top-k logits; if 0, no top-k sampling is applied.

    Returns:
        List[str]: A list of generated SMILES strings.
    """
    model.eval()
    batch_size = start_sequence.size(0)
    generated_sequences = start_sequence.clone().to(device)  # Clone and move to device
    # expand generated_sequences to the max_length with padding tokens
    padding = torch.full((batch_size, max_length - generated_sequences.size(1)), PAD, dtype=torch.long).to(device)
    generated_sequences_input = torch.cat([generated_sequences, padding], dim=1)[:,:-1].to(device)
    
    with torch.no_grad():
        # Forward pass through the
        for current_len in range(max_length - start_sequence.size(1)):
            
            # Forward pass through the model
            logits = model(zeo, syn, generated_sequences_input)
            # Extract the logits for the last time step
            next_token_logits = logits[:, -1, :]  # (batch_size, vocab_size)

            # Apply temperature scaling
            next_token_logits = next_token_logits / temperature

            # Apply top-k filtering
            if top_k > 0:
                top_k_logits, top_k_indices = torch.topk(next_token_logits, top_k, dim=-1)
                mask = torch.full_like(next_token_logits, float('-inf'))
                mask.scatter_(dim=-1, index=top_k_indices, src=top_k_logits)
                next_token_logits = mask

            # Convert logits to probabilities
            next_token_probs = F.softmax(next_token_logits, dim=-1)

            # Sample from the probability distribution
            next_token = torch.multinomial(next_token_probs, num_samples=1)  # (batch_size, 1)
            
            # Get the most likely next token
            # next_token = torch.argmax(next_token_logits, dim=-1, keepdim=True)

            # Append the generated token to the sequence
            generated_sequences = torch.cat([generated_sequences, next_token], dim=1)
            # update the input sequence for the next iteration
            generated_sequences_input[:, current_len] = next_token.squeeze(1)

            # Check if all sequences have reached the end token
            if all(next_token[i].item() == EOS for i in range(batch_size)):
                break

    # Decode the generated sequences into SMILES strings
    generated_smiles = []
    for seq in generated_sequences:
        # Convert indices to characters, ignoring padding and start tokens
        # check if the generated sequence contains the end token, if meet, stop decoding
        smiles = ''
        for idx in seq:
            if idx.item() == EOS:
                break
            elif idx.item() != PAD and idx.item() != SOS:
                smiles += vocab.itos[idx.item()]
        generated_smiles.append(smiles)

    return generated_smiles

# %%
def sample_clamer(temp, model, sample_dataloader, device, vocab):
    '''ArithmeticError
    Generate SMILES strings using the trained GPT model with sampling.
    
    Args:
        temp (float): The temperature parameter for sampling.
        model (CLAMER): The pre-trained GPT model for token generation.
        sample_dataloader (DataLoader): The data loader for the SMILES dataset.
        device (torch.device): The device on which to run the generation.
        vocab: The vocabulary object for encoding and decoding SMILES strings.
    
    Returns:
        List[float]: A list of negative log-likelihoods for the generated SMILES strings.
        List[str]: A list of generated SMILES strings.
    '''
    sample_nll_total = []
    smiles_gen_total = []
    with torch.no_grad():
        for batch_idx, (zeo, syn, tgt, positive_smiles, negative_smiles) in enumerate(tqdm(sample_dataloader)):
            # Generate the target sequence for the model
            target = [SOS] + [PAD] * 218
            tgt_seq = torch.LongTensor(target).unsqueeze(0).expand(zeo.size(0), len(target)).to(device)
            batch_size = zeo.size(0)
            # Move input tensors to the device
            zeo, syn = zeo.to(device), syn.to(device)
            smiles_gen = [[''] * batch_size][0]
            sample_nll = [0] * batch_size
            finished = np.array([False] * batch_size, dtype=object)
            end_char = '<eos>'
            for i in range(218):
                net_out = model(zeo, syn, tgt_seq)[:, i + 2, :]
                o = F.softmax(net_out, dim=-1).cpu().detach().numpy()
                # sample temp
                if temp != 0:
                    temp = abs(temp)  # No negative values
                    next_char_probs = np.log(o) / temp
                    next_char_probs = np.exp(next_char_probs)
                    next_char_probs = next_char_probs.astype(float)
                    next_char_probs = (next_char_probs.T / (next_char_probs.sum(axis=1))).T
                    sampleidc = torch.tensor(
                        [np.random.multinomial(1, next_char_prob, 1).argmax() for next_char_prob in
                            next_char_probs])
                else:
                    sampleidc = torch.tensor(np.argmax(o, axis=1))

                samplechars = [vocab.itos[idx] for idx in sampleidc.numpy()]

                for idx, samplechar in enumerate(samplechars):
                    if not finished[idx]:
                        if samplechar != end_char:
                            # Append the SMILES with the next character
                            smiles_gen[idx] += samplechar
                            tgt_seq[:, i + 1] = sampleidc.to(device)
                            # Calculate negative log likelihood for the selected character
                            sample_nll[idx] -= np.log(o[idx][sampleidc[idx]])
                        else:
                            finished[idx] = True
                            # print("SMILES has finished at %i" %i)
                # If all SMILES are finished, i.e. the end_char "<eos>" has been generated, stop the generation
            if finished.sum() == len(finished):
                sample_nll_total += sample_nll
                smiles_gen_total += smiles_gen
                    
    return sample_nll_total, smiles_gen_total

# %%
# generate the smiles for the test dataset
sample_nll_total, generated_smiles = sample_clamer(temp=0.7, model=model, sample_dataloader=test_dataloader, device=device, vocab=vocab)
target_smiles = []
for i, (zeo, syn, tgt, _, _) in enumerate(tqdm(test_dataloader)):
    tgt = tgt.to(device)
    # convert the tgt to smiles
    tgt_smiles = []
    for seq in tgt:
        smiles = ''
        for idx in seq:
            if idx.item() == EOS:
                break
            elif idx.item() != PAD and idx.item() != SOS:
                smiles += vocab.itos[idx.item()]
        tgt_smiles.append(smiles)
    target_smiles.extend(tgt_smiles)
print('the total num of target smiles is :', len(target_smiles))
# Out:
# 100%|██████████| 232/232 [06:51<00:00,  1.77s/it]
# 100%|██████████| 232/232 [00:39<00:00,  5.86it/s]
# the total num of target smiles is : 14803

# %%
print('the generated smiles are :', generated_smiles[1:3])
print('the target smiles are :', target_smiles[1:3])
# Out:
# the generated smiles are : ['C(CC[n+]1ccn(C)c1)CCCCCC[n+]1cn(C)cc1', 'C(C)C([n+]1cn(C(C)C)cc1)C']
# the target smiles are : ['C(CCC[n+]1ccn(c1)C)CCCC[n+]1ccn(C)c1', 'c1[n+](cn(c1)C)CCCCCCCC[n+]1cn(cc1)C']

# %%
# calculate the metrics
print('Validity rate:', validity_rate(generated_smiles))
print('Uniqueness rate:', uniqueness_rate(generated_smiles))
print('Novelty rate:', novelty_rate(generated_smiles, target_smiles))
print('Reconstructability rate:', reconstructability_rate(generated_smiles, target_smiles))
print('Novelty rate:', novelty_rate(generated_smiles, target_smiles))
print('IntDiv:', IntDiv(generated_smiles))
# print('KL-divergence:', KL_divergence(target_smiles), generated_smiles))
print('FCD score:', FCD_score(target_smiles, generated_smiles))
# Out:
# [01:51:52] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 6
# [01:51:52] Can't kekulize mol.  Unkekulized atoms: 0 1 2 7 8
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'CC1[N+]2(CCCC)CCCC1C'
# [01:51:52] SMILES Parse Error: ring closure 5 duplicates bond between atom 5 and atom 6 for input: '[N+]1(CC2C3C4C5C5C[N+](CC5C4C(C2C1)C=C3)(C)C)(C)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CC[N+](CCC)(C)C2C(C1)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2[N+](CCC1)(CCCC)CCCC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(CC1)CC(C)N1CC2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC(CN1CC)[N+]1(C)CCCC1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CCCC2[N+]1(C)CC1CC2CC2[N+]2(CCCC2)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CCC2[N+]3(C)C(CC(C3)[N+]4(CCCCC4)C)CC2C'
# [01:51:52] Can't kekulize mol.  Unkekulized atoms: 0 1 3 8 9
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1(CC)[N+]2(CCCCCC[N+]34CCC(CC4)CC3)CCC1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CC[N+](C)(CCCCC)C1CCCC1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C(C)C[N+]2(CC1)CCCCCC[N+]12CCN(CC2C)CC1'
# [01:51:52] Explicit valence for atom # 1 N, 4, is greater than permitted
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(C1)CC1C3C=CC(C12)C1C3C[N+](CC3C1)(C)C'
# [01:51:52] Explicit valence for atom # 13 N, 4, is greater than permitted
# [01:51:52] Explicit valence for atom # 13 N, 4, is greater than permitted
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+]2(C1)CC(C)N1CC2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CC2CCCCC2[N+]2(CCCCCC[N+]2(C)C1CCCC2)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CC(C)[N+]2(CCCC)CCCC2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C(CCCCCCCCC[N+]12CC(C)N(CC2)C(C)CC1)[N+]12CCN(CC2)C(C)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C(CC)CC1)CCCCCC[N+]12CC(N(CC1)CC2)C'
# [01:51:52] SMILES Parse Error: syntax error while parsing: C1[N+]2(CNN+](C1)(CC2)CCC[N+]12CNC(CC2)CC1)C
# [01:51:52] SMILES Parse Error: Failed parsing SMILES 'C1[N+]2(CNN+](C1)(CC2)CCC[N+]12CNC(CC2)CC1)C' for input: 'C1[N+]2(CNN+](C1)(CC2)CCC[N+]12CNC(CC2)CC1)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CCC2[N+](C1)(C)CCCCC[N+]1(C2CCC1CCC2)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CCC([N+]2(CCCC[N+]2(C)C3CCCC2)C)C1'
# [01:51:52] SMILES Parse Error: extra open parentheses for input: 'C([N+]1(CCCCC[N+]2(C)CCCCCC2)CCCCC1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(CC1)CCCC[N+]1(C)CCCC1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1CC(C3)([n+]1ccn(C45CC6CC(CC(C4)C6)C4)c1)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2(n3cc[n+](c3)C34CC5CC(C4)CC(C5)C4)CC3CC1CC(C3)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1([n+]1ccn(C45CC6CC(CC(C4)C6)C6)c1)CC(C3)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C[N+]1(C)CCCCC[N+]2(C)CCCCC2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1CC(C2)([n+]1cn(C45CC6CC(CC(C6)C6)C4)cc1)C3'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12(OCC(c3ccccc3)O2)CC[N+](C)(C)CC2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C[N+](C)(CCC1)C1CC2CC(c3ccccc3)CC2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'c1cc(ccc1)C[N+](C)(C)CC1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC3([n+]4ccn(c4)C45CC6CC(CC(C4)C6)C6)CC(C2)CC1C3'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+](C)(C1CCCC[N+]1(C)CCCCCC)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12CC(C3(C)C)C(C2)CCC[N+]1(CC)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1(C)(C2CC1C(CC[N+]1(CC)CC)C2)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C(C)(C2CC1[N+]1(CCCCC1)C)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC([n+]4cn(C56CC7CC(CC(C7)C6)C6)cc4)(C2)CC1C3'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C1)([n+]1cn(C45CC6CC(CC(C4)C6)C6)cc1)CC(C2)C3'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12CC(CC2CCC1)C[N+](C)(C)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1(C3)n1cc[n+](C34CC5CC(CC(C4)C5)C4)c1)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1([n+]1ccn(C45CC6CC(C6)CC(C5)C6)c1)C3)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CC2C3CCC(C3)C2C1C[N+](C)(C)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC3([n+]4cn(C56CC7CC(CC(C6)C7)C7)cc4)CC1CC(C3)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2[N+](CCCC[N+]3(CCCCC3)C)(C1)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1CC([n+]1ccn(C45CC6CC(CC(C5)C6)C6)c1)C3'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C[N+](CC)(CC)CC4C(C=1)C1C[N+](CC)(CC)CC32'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C4C5C(C[N+](C)(C)C5)C(C2C[N+](C1)(C)C)C=C3'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C[N+](CC)(CC)CC4C(C=1)C1C[N+](CC)(CC21)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C(C4C=CC3C3C[N+](CC)(CC)C4)C2C[N+](CC)(CC)C1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C[N+]1(CC2C3C4C5C(C[N+](C)(C)CC5C(C3C[N+](C)(C)CC)C)C(C2)C1)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C=CC(C4C[N+](CC)(CC)CC43)C2C[N+]1(CC)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC4C(C3C[N+](CC)(CC)CC32)C=C1)(CC)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C(C[N+](C4)(CC)CC)C(C3C[N+](CC)(CC)CC32)C=1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC)(CC3C(C3C4C[N+](CC)(C4)CC)C2C=C1)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC)(CC4C(C3C[N+](CC)(CC)CC32)C=C1)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1=CC2C3C(C[N+](CC)(C4)CC)C1C1C[N+](CC)(CC)CC31'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C(C(C4C[N+](CC34)(CC)CC)C2C=C1)C[N+](CC)(CC)C2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C4C=CC(C4C[N+](CC)(CC)CC43)C2C[N+](C1)(CC)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC)(CC3C(C3C4C[N+](CC)(CC)C4)C2C=C1)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C[N+](CC)(CC)CC4C(C=1)C1C[N+](CC)(CC)CC32'
# [01:51:52] SMILES Parse Error: ring closure 5 duplicates bond between atom 6 and atom 7 for input: 'C[N+]1(CC2C3C4C5C5C[N+](C)(C)CC5C4C(C2C1)C=C3)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C4C[N+](CC4C(C3C[N+](CC)(CC)C3)C(C=C2)C1)(CC)CC'
# [01:51:52] SMILES Parse Error: ring closure 2 duplicates bond between atom 0 and atom 21 for input: 'C12C3C(C4C[N+](CC)(CC)CC43)C(C3C[N+](CC)(CC)CC21)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C4C5C5C[N+](CC5C4C(C=C4)C1C[N+](C)(C)C5)(C)C3'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C(CCCCC[N+]12CC(C)N(CC1)CC2)C[N+]1(CCN(CC1)CC2)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC)(CC3C(C3C1C[N+](CC)(CC)CC)C2)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C[N+](CC)(CC4C(C=1)C1C2C[N+](CC)(CC)C1)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C[N+](CC)(CC2C2C=CC1C1C2C[N+](CC12)(CC)CC)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12C3C[N+](CC3C(C=C1)C1C3C[N+](CC)(CC)CC31)(CC)CC'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C1)CC(C3)(C3)[N+](C)(C)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(CN3CN1CN3C3)CN1CC2'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(C)C(CCCc3ccc2)C1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C(C[N+](C)(C)C)C2C(C)(C)C(C2)C1C2'
# [01:51:52] Explicit valence for atom # 8 N, 4, is greater than permitted
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'c1cccc(C[N+]2(CCC(CCCC3CC[N+](CC3)(C)Cc3ccccc3)CC2)c1)c1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1c2ccccc2C[N+]21CCC(CC2)CCCC1CC[N+](C)(CC2)Cc1ccccc1'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1C2C(CCC1)CCC[N+]1(C2)C'
# [01:51:52] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+]2(CCCC3CCCCC13)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CCCCC2CCC[N+]2(CC1)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 5
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 3 4 5 6 7
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 12
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 16 17 18 19
# [01:51:53] Explicit valence for atom # 7 N, 4, is greater than permitted
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1[N+](C)(C)CCCCC[N+]2(C)CCCC2C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(CC1)C(C)(CCCC[N+]1(C)CC(CCC2)C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C[N+](C)(C)CC2C2C=CC1C1C2C[N+](C)(C)CC21'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2C[N+](CC(C1)C)(CC)CC'
# [01:51:53] SMILES Parse Error: ring closure 2 duplicates bond between atom 3 and atom 4 for input: 'C1CCC2N2C(CC1[N+]1(C(C2)CCCC1)CC)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3[N+]4(C(CC([N+]2(CC)CCCC1)C3)C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: '[N+]12(C)C3CC([N+]4(CC)C(C3)CC2CCCC1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCC2[N+](C)(C3CC4[N+](C(C1)C2)(C)CCCC4)CC'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1cc(C<unk>)ccc1C[N+](C)(C)CC1CC[N+](C)(C)CC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1cc(C<unk>)ccc1C[N+](C)(C)CC1CC[N+](C)(C)CC1' for input: 'c1cc(C<unk>)ccc1C[N+](C)(C)CC1CC[N+](C)(C)CC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2[N+](C)(C3CC(CC4[N+]2(C)C3)CCC1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC(CC3[N+]2(CC1)C)[N+]1(C)CCCCC1C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+]2(C)C3CC4[N+](C(C1)C2)(C)CCCC4'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(C)C3CC4[N+](C)(C)C(CC2CCC1)C3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3[N+]4(C(CC(C2CCC1)[N+]1(C)CCCC1)C3)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C)CC3[N+]4(C)C(CC(C3)C2CC1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2[N+](C)(C3CC4[N+](C)(CC1C3)CCCC2)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3[N+]4(C)C(CC(C3)[N+]2(C)CCCC1)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+]2(CC3CC([N+]4(C)C(CC2C3)C)C1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC2[N+](C)(C3CC4CCCC[N+]4(C(C3)CCCC4)C)CCCC2C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC3[N+](C)(CCCC3)C(C2)C2CC([N+]2(C)CCCCC2)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C3C(CC1)CC1[N+]3(CCCCC3C1)C)CCCC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC(C2(C)C)C(C1)C[N+](C)(C)CC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1ccccc1C[N+]1(CCCCC[N+]1(C)CCCCC1)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 5
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C[N+](C)(C)CCCCC[N+]2(CCCCC2)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 20 24
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCCCCCCC[N+]1(C)CCCCCC[N+]1(C)CCC(CCCC1)CCCC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C(CCCC[N+](C)(C)C)C[N+](C)(Cc1ccc(C[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCCCCCCCCCCCC)(C)C)C'
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCCCCCCCCCCCCC[N+](C)(C)Cc1ccc(cc1)C[N+](C)(C)CCCCCC[N+](C)(C)Cc1ccc(C[N+](C)(CCCCCC[N+](C)(C)C)C)cc1'
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCCCCCCCCCCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](C)(CCCCCC[N+](CCCCCCCCCCCCCCCC)(C)C)C'
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCCCCCCCCCCCCCC[N+](CCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCCCCCCCCCCCC)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 14 15 16 51 52
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCCCCCCCCCCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](CCCCCC[N+](C)(CCCCCCCCCCCCCCCC)(C)C)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 52 53
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCCCCCCCCCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](CCCCCC[N+](C)(C)CCCCCCCCCCCCCCCC)(C)C'
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CC[N+](C)(Cc1ccc(cc1)C[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](C)(C)Cc1ccc(cc1)C[N+](CCCCCC[N+](C)(C)C)C)(C)C'
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCC[N+](C)(C)Cc1ccc(C[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](C)(Cc2ccc(cc2)C[N+](C)(CCCCCC[N+](C)(C)C)cc2)C)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 29 63 64
# [01:51:53] Explicit valence for atom # 36 N, 4, is greater than permitted
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCCCCCCCCCCCCCC[N+](CCCCCC[N+](C)(C)CCCCCC[N+](CCCCCC[N+](CCCCCC[N+](C)(C)CCCCCCCCCCCCCCCC)(C)C)(C)C)C'
# [01:51:53] Explicit valence for atom # 12 N, 4, is greater than permitted
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C(CCCCCCCCCCCCCC)CC[N+]1(CCC(CCCC2CC[N+](C)(CCCCCC[N+](C)(CCCCCCCCCCCCCCCC)C)CC1)C)CCCCCCCCC'
# [01:51:53] Explicit valence for atom # 42 N, 4, is greater than permitted
# [01:51:53] SMILES Parse Error: extra close parentheses while parsing: C(CCCCC[N+](C)(C)C)CCCC[N+](C)(Cc1ccc(cc1)C[N+](C)(CCCCCC[N+](C)(CCCCCC[N+](C)(C)C)C)C)C)CCCCCCCC
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C(CCCCC[N+](C)(C)C)CCCC[N+](C)(Cc1ccc(cc1)C[N+](C)(CCCCCC[N+](C)(CCCCCC[N+](C)(C)C)C)C)C)CCCCCCCC' for input: 'C(CCCCC[N+](C)(C)C)CCCC[N+](C)(Cc1ccc(cc1)C[N+](C)(CCCCCC[N+](C)(CCCCCC[N+](C)(C)C)C)C)C)CCCCCCCC'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 20 54 55
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C(CCCCCCCCCCCCCC)CC[N+]1(C)CCC(CCCC2CC[N+](CCCCCC[N+](CC2)(CCCCCCCCCCCCCCCC)(C)CC2)(CCCCCCCCCC)CC1)C'
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCCCCCCCCCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCCCCCCCCCCCC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCCCCCCCCC[N+]1(CCCCCC[N+]1(C)CCC(CCCC1)CC1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C(CCCCC[N+](C)(C)Cc1ccc(C[N+](C)(CCCCCC[N+](C)(C)C)cc1)C)C[N+](CCCCCC[N+](Cc1ccc(C[N+](C)(C)C)C)(C)C)(C)C'
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCCCCCCCCCCCCCC[N+](C)(C)CCCCCC[N+](C)(C)CCCCCC[N+](C)(CCCCCC[N+](C)(CCCCCCCCCCCCCCCC)C)C'
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(CCCCCCCCCCCCCCC[N+]1(CCC(CC1)CCCC1CC[N+](CCCCCC[N+](C)(CCCCCCCCCCCCCCCC)C)(C)C)CCCCCCCCCC'
# [01:51:53] Explicit valence for atom # 17 N, 4, is greater than permitted
# [01:51:53] Explicit valence for atom # 24 N, 4, is greater than permitted
# [01:51:53] Explicit valence for atom # 46 N, 4, is greater than permitted
# [01:51:53] Explicit valence for atom # 26 N, 4, is greater than permitted
# [01:51:53] Explicit valence for atom # 0 N, 4, is greater than permitted
# [01:51:53] Explicit valence for atom # 0 N, 4, is greater than permitted
# [01:51:53] Explicit valence for atom # 43 N, 4, is greater than permitted
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C3C4C5C(C(C=C4)C3C[N+](CC)(CC)C4)C2C[N+](CC)(CC)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: '[N+]1(CC2C(C3C4C5C[N+](CC5C(C2C1)C=C3)(C)C)C)(CC)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C3C4C=CC(C4C[N+](CC)(CC)CC43)C2C[N+](CC)(CC)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C(C)[N+]1(CC2C3(C=CC(C2C1)C1C[N+](CC)(CC23)CC)C)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(CCCCCC[N+]34CCN(C1)CC3)CCN1CC2'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 18 21 22
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CCCCC1CC[N+](C)(CC1)CC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3[N+]4(C)C(CC(C2CCC1)[N+]1(C)CCCC1)CC(C3)C3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1N2CC[N+](CC2)(CC2)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC2CC3[N+]4(C)CCCCC4CC(C2CC1)[N+]1(C3)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12[N+]3(CCCCC3CC(C[N+]3(CCCCC1)C)C2)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1c2ccccc2C[N+](CC1)(CCCCCC[N+]1(C)Cc1ccccc1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCCCCC1[N+]1(C)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12[N+](CCCC2)(C2CC3[N+](CC2C2)(CCCC3)C)CCCC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'CC1CCCC2CC[N+](CC2)(C)CCCCCC[N+]2(C1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1(CC[N+](C)(Cc2ccccc2)C)CC[N+](C)(C)Cc1ccccc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC3[N+](CC(CC3)C2)(C)CC2CC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(CC)C(C1)CC1[N+]3(C)C(CCCC3)CC2CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2[N+](CCCC1)(C2CC([N+](C)(C)C)CCCC2)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CCCCN1C1CC3[N+](C)(C)C(C1)CCCC3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC3[N+]4(C(CCCC4)C3CC1[N+]1(C)CCCC2)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'CC1(C)C2CC1[N+]1(C)CCCC1C2CCCC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12[N+](CCC[N+]34CC)(CC)CCCCC3CC1CC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1c(C[N+](C)(C)CC2CC[N+](C)(C)Cc3ccccc2)cccc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1(CC[N+](Cc2ccccc2)(C)C)CC[N+](C)(C)Cc1ccccc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C(CCCC1)CC[N+](C)(CC1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CCCC1CC[N+](CC1)(C)CC2'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 18 19 20 21 22 23 24
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1cc2ccc1Cn1cc[n+](CCCCCC[n+]3cn(cc3)Cc3cc2)c1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1c[n+]2Cc3ccc(cc3)Cn3cc[n+](c3)CCCCCC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1cccc2c1Cn1cc[n+](CCCCCC[n+]3cn(cc3)Cc3cc2)c1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CCCC3CC[N+](C)(CC2)Cc2ccc(C[N+](C)(C1)CC2)cc2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1cc2C[N+]3(C)CCC(CC3)CCCC3CC[N+](C)(CC2)Cc1ccc2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1c[n+]2CCCCCC[n+]3ccn(CCCCCC[n+]4cn1cc4)c3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1[n+]2CCCCCC[n+]3cn(cc3)Cc3ccc(Cn1cc3)cc3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC2CC[N+]1(C)CCCCCC[N+]1(C)CCC(CCCC2CC[N+](C)(CC2)CC1)CC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1c2C[N+]3(CCC(CCCC4CC[N+](C)(CC1)CCCCCC3)Cc2ccc2)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC[N+](CC2)(Cc2ccc(cc2)C[N+]2(CCC(CC2)CC2)C)C1'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 7 8 9 16 17 20 21 22 23 24
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1c2ccc(cc2)C[N+]2(CCC(CCCC(C1)CCCC1CC2)CC2)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC2CC[N+]1(C)CCCCCC[N+]1(C)CCC(CCCC2CC[N+](C)(CC2)Cc2ccccc2)CC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(C)Cc3ccc(C[N+]4(C)CCC(CCCC(C1)CC2)cc3)c2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC2CC[N+]1(C)CCCCCC[N+]1(C)CCC(CCCC2CC[N+](CC2)(CC1)C)CC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1c2ccc(Cn3cc[n+](CCCCCC[n+]4cn(CCCCC4)cc4)cc3)c2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1c2ccc(c1)Cn1cc[n+](c1)CCCCCC[n+]1cn(cc1)Cc1ccccc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'n1(Cc2ccc(Cn3cc[n+](CCCCCC[n+]3ccn(C2)c3)c2)cc1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC[N+](Cc3ccc(cc3)C[N+]3(CCC(CCCC(C1)CC2)C)C)(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCC2CC[N+]1(C)Cc1ccc(C[N+]3(C)CCC(CC3)CCCC(C)C)cc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1c[n+]2CCCCCC[n+]3cn(Cc4ccc(cc4)C2)cc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C[N+]12CCC(CCCC3CC[N+](CC3)(Cc3ccc(C2)cc3)CC2)CC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1cccc2C[N+]3(C)CCC(CC3)CCCC3CC[N+]1(C)CC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1cc2ccc1Cn1cc[n+](CCCCCC[n+]3cn(Cc(c3)cc3)cc2)c1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1cccc2Cn3c[n+](cc3)CCCCCC[n+]3cn(C2)cc3'
# [01:51:53] SMILES Parse Error: extra open parentheses for input: 'C(Cn1c[n+](CCCCCC[n+]2ccn(c2)Cc2ccccc2)cc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(Cc3ccc(C[N+]4(C)CCC(CCCC(CC2)C1)CC3)cc3)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC[N+](CCCCCC[N+]3(C)CCC(CC1)CCCC1)(C)CC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(C)CCC(CC2)CCCC2CC[N+](CC2)(CCCCCC2)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1c2ccc(Cn3c[n+](CCCCCC[n+]4ccn(CCC1)cc4)c2)cc2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1ccc2C[N+]3(C)CCC(CCCC1CC[N+](C)(Cc1)CC3)Cc1ccccc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CCCC3CC[N+](C)(CC2)Cc2ccc(C[N+](C)(CC2)C)cc2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c12ccc(cc1)Cn1cc[n+](CCCCCC[n+]2ccn(c2)Cc2ccccc2)c1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC2CCCC3CC[N+](C)(CC23)Cc2ccc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1cccc2Cn3cc[n+](CCCCCC[n+]4ccn(CCCCCc(c1)c2)c2)c3'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 8 9 28
# [01:51:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2C3C=CC(C4C[N+](CCC)(CCC)CC43)C2C[N+]1(CCC)C(C)C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C3C4C(C(C2C[N+](CC)(CCC)C1)C=C3)C[N+](C(C)C)(CCC)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2C3C=CC(C4C3C3C[N+](C4)(C(C)C)CCC2)C[N+]1(CCC)C(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: '[N+]1(CCC)(C(C)C)CC2C3C4C(C[N+](C4)(CCC)C(C)C)C(C)C2C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C3C=CC(C4C[N+](CC14)(CCC)CCC)C1C[N+](CC21)(C(C)C)C(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C[N+]1(CC2C3C4C=CC(C5C[N+](CC54)(C(C)C)CC)C2C1)C(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C3C4C(C(C=C3)C2C[N+](CC12)(CCC)CCC)C[N+](C(C)C)(C(C)C)CCC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC2CC3CC(C2[N+]1(CCCC[N+]1(C)C2)CCCC3)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCC[N+]1(CC(C)(C=1)C)C(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C[N+](C)(CCC21)C'
# [01:51:53] SMILES Parse Error: extra close parentheses while parsing: C1CCC2C1CC2)N
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCC2C1CC2)N' for input: 'C1CCC2C1CC2)N'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C(CC([N+](C)(C)C2)C2)(CC1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2C(CC1)C[N+](C2)(C)CCC2'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 7 8 9 10
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 8 9 10
# [01:51:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [01:51:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 1 2 14 16 17
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 1 2 14 16 17
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 4 15
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 16
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 1 2 4
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 7
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 14 15
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(C2)CC1([n+]1cn(C45CC6CC(CC(C6)C6)C5)cc1)C3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC(CC1)CC(C2)C[N+]2(C)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 5
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CCCC[N+](C)(C2CCCC1)C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC(C2(C)C)C(CC[N+]2(CC)C)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC(C2(C)C)C(C)CC[N+]2(CC)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2(C)C[N+](C)(CC(C3C2)CC1(C)C)C'
# [01:51:53] SMILES Parse Error: extra close parentheses while parsing: CC12CC(C)(C)CC(C)(C)C2)[N+](C)(C)C1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'CC12CC(C)(C)CC(C)(C)C2)[N+](C)(C)C1' for input: 'CC12CC(C)(C)CC(C)(C)C2)[N+](C)(C)C1'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 5
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1(CC2C(C)C(C[N+](C)(C)C2)(C)C)(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C(C)(C(C2)[N+](C)(CCC1C2)C)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 4 6
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCC2CCCCC[N+]21CCCC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCC2CCCCC[N+]21CCCC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C[N+](C)(C)C(C2CC1(C)C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1(C)C2CC(C([N+](C)(C)C)C2)(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C123CCCCC2(CCCC1)C[N+]3(CCCC3)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 3 4 12 13 14 15 16 18
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 1 2 4 13 14
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c12c3[N+](C)(CCCc2ccc1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1ccc2C[N+]3(CCCc(c23)C)Cc2c1'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 9 10 11 12 13 14 15
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1c2c3CCC[N+]3(CCC1)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(CCCc3cccc(CCC2)c23)CCCC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1ccc2CCC[N+]3(C)CCCc12'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c12c3c(C[N+](C)(C2)C)ccc1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]2(C)C(C1)CCCc2ccc2'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 11 12
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 12
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 5 6 10 11 12
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 5 6 10 11 12
# [01:51:53] Explicit valence for atom # 5 C, 5, is greater than permitted
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCC2[N+](C2CCCC21)(CC)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2[N+](CCCC1)(CC)C2CCCCC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12[N+](C(CCC1)C1CC2CC1)(CCCC3)CC'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CC[N+](CC2(c3ccc(cc3)C<unk>)CCCC2)(CCCCCCC1)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CC[N+](CC2(c3ccc(cc3)C<unk>)CCCC2)(CCCCCCC1)C' for input: 'C1CC[N+](CC2(c3ccc(cc3)C<unk>)CCCC2)(CCCCCCC1)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCCCCC[N+](CC2(CCCC2)c2ccc(C<unk>)cc2)(C)C1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCCCCC[N+](CC2(CCCC2)c2ccc(C<unk>)cc2)(C)C1' for input: 'C1CCCCCCC[N+](CC2(CCCC2)c2ccc(C<unk>)cc2)(C)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC[N+](C)(C)CC1(CC1)c1ccccc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C(C[N+]2(CCCCCCC2)C)(CCCC1)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C(C[N+]2(CCCCCCC2)C)(CCCC1)c1ccc(C<unk>)cc1' for input: 'C1C(C[N+]2(CCCCCCC2)C)(CCCC1)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1(C<unk>)ccccc1C1(C[N+]2(CCCCCCC2)C)CCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1(C<unk>)ccccc1C1(C[N+]2(CCCCCCC2)C)CCCC1' for input: 'c1(C<unk>)ccccc1C1(C[N+]2(CCCCCCC2)C)CCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1c(ccc(c1)C<unk>)C1(CCCC1)C[N+]1(C)CCCCCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1c(ccc(c1)C<unk>)C1(CCCC1)C[N+]1(C)CCCCCCC1' for input: 'c1c(ccc(c1)C<unk>)C1(CCCC1)C[N+]1(C)CCCCCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1c(C<unk>)ccc(c1)C1(CCCC1)C[N+]1(CCCCCCC1)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1c(C<unk>)ccc(c1)C1(CCCC1)C[N+]1(CCCCCCC1)C' for input: 'c1c(C<unk>)ccc(c1)C1(CCCC1)C[N+]1(CCCCCCC1)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCC[N+](C1)(CC1(CCCC1)c1ccc(cc1)C<unk>)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCC[N+](C1)(CC1(CCCC1)c1ccc(cc1)C<unk>)C' for input: 'C1CCCC[N+](C1)(CC1(CCCC1)c1ccc(cc1)C<unk>)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C[N+](CCC1)(CC1(CCCC1)c1ccc(cc1)C<unk>)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C[N+](CCC1)(CC1(CCCC1)c1ccc(cc1)C<unk>)C' for input: 'C1C[N+](CCC1)(CC1(CCCC1)c1ccc(cc1)C<unk>)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CC(C[N+]2(CCCCCCC2)C)(c2ccc(cc2)C<unk>)CC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CC(C[N+]2(CCCCCCC2)C)(c2ccc(cc2)C<unk>)CC1' for input: 'C1CC(C[N+]2(CCCCCCC2)C)(c2ccc(cc2)C<unk>)CC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1(C[N+]2(C)CCCCCCC2)(CCCC1)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1(C[N+]2(C)CCCCCCC2)(CCCC1)c1ccc(C<unk>)cc1' for input: 'C1(C[N+]2(C)CCCCCCC2)(CCCC1)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCC(C[N+]2(CCCCCCC2)C)(c2ccc(cc2)C<unk>)C1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCC(C[N+]2(CCCCCCC2)C)(c2ccc(cc2)C<unk>)C1' for input: 'C1CCC(C[N+]2(CCCCCCC2)C)(c2ccc(cc2)C<unk>)C1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCC(C[N+]2(C)CCCCCCC2)(CC1)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCC(C[N+]2(C)CCCCCCC2)(CC1)c1ccc(C<unk>)cc1' for input: 'C1CCC(C[N+]2(C)CCCCCCC2)(CC1)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCCC[N+](CC2(c3ccc(C<unk>)cc3)CCCC2)(CCCC1)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCCC[N+](CC2(c3ccc(C<unk>)cc3)CCCC2)(CCCC1)C' for input: 'C1CCCCC[N+](CC2(c3ccc(C<unk>)cc3)CCCC2)(CCCC1)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1c(C<unk>)ccc(c1)C1(CCCC1)C[N+]1(CCCCCCC1)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1c(C<unk>)ccc(c1)C1(CCCC1)C[N+]1(CCCCCCC1)C' for input: 'c1c(C<unk>)ccc(c1)C1(CCCC1)C[N+]1(CCCCCCC1)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CC(C[N+]2(CCCCCCC2)C)(c2ccc(cc2)C<unk>)CC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CC(C[N+]2(CCCCCCC2)C)(c2ccc(cc2)C<unk>)CC1' for input: 'C1CC(C[N+]2(CCCCCCC2)C)(c2ccc(cc2)C<unk>)CC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1[N+](CCCC2(CCCC2)c2ccc(C<unk>)cc2)(C)CCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1[N+](CCCC2(CCCC2)c2ccc(C<unk>)cc2)(C)CCCC1' for input: 'C1[N+](CCCC2(CCCC2)c2ccc(C<unk>)cc2)(C)CCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1(C<unk>)ccc(C2(CCCC2)C[N+]2(C)CCCCC2)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1(C<unk>)ccc(C2(CCCC2)C[N+]2(C)CCCCC2)cc1' for input: 'c1(C<unk>)ccc(C2(CCCC2)C[N+]2(C)CCCCC2)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C(CCC1)(C[N+]1(C)CCCCCC1)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C(CCC1)(C[N+]1(C)CCCCCC1)c1ccc(C<unk>)cc1' for input: 'C1C(CCC1)(C[N+]1(C)CCCCCC1)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C(CCC1)(C[N+]1(CCCCCCC1)C)c1ccc(cc1)C<unk>
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C(CCC1)(C[N+]1(CCCCCCC1)C)c1ccc(cc1)C<unk>' for input: 'C1C(CCC1)(C[N+]1(CCCCCCC1)C)c1ccc(cc1)C<unk>'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCC(C[N+]2(C)CCCCCCC2)(c2ccc(C<unk>)cc2)C1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCC(C[N+]2(C)CCCCCCC2)(c2ccc(C<unk>)cc2)C1' for input: 'C1CCC(C[N+]2(C)CCCCCCC2)(c2ccc(C<unk>)cc2)C1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCC1(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCC1(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>' for input: 'C1CCCC1(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CC(C[N+]2(O)CCCC2)(F)c2ccc(C<unk>)cc2
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CC(C[N+]2(O)CCCC2)(F)c2ccc(C<unk>)cc2' for input: 'C1CC(C[N+]2(O)CCCC2)(F)c2ccc(C<unk>)cc2'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCCCC[N+]1(C)CC1(c2ccc(cc2)C<unk>)CCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCCCC[N+]1(C)CC1(c2ccc(cc2)C<unk>)CCCC1' for input: 'C1CCCCCC[N+]1(C)CC1(c2ccc(cc2)C<unk>)CCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCC1(c1ccc(C<unk>)cc1)C[N+]1(C)CCCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCC1(c1ccc(C<unk>)cc1)C[N+]1(C)CCCCC1' for input: 'C1CCCC1(c1ccc(C<unk>)cc1)C[N+]1(C)CCCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCCC[N+](C)(CC2(CCCC2)c2ccc(cc2)C<unk>)C1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCCC[N+](C)(CC2(CCCC2)c2ccc(cc2)C<unk>)C1' for input: 'C1CCCCC[N+](C)(CC2(CCCC2)c2ccc(cc2)C<unk>)C1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: [N+]1(CCCCCCC1)(C)CC1(c2ccc(cc2)C<unk>)CCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES '[N+]1(CCCCCCC1)(C)CC1(c2ccc(cc2)C<unk>)CCCC1' for input: '[N+]1(CCCCCCC1)(C)CC1(c2ccc(cc2)C<unk>)CCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCCC[N+]1(C)CC1(CCCC1)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCCC[N+]1(C)CC1(CCCC1)c1ccc(C<unk>)cc1' for input: 'C1CCCCC[N+]1(C)CC1(CCCC1)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1c(C2(CCCC2)C[N+]2(CCCCC2)C)ccc(C<unk>)c1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1c(C2(CCCC2)C[N+]2(CCCCC2)C)ccc(C<unk>)c1' for input: 'c1c(C2(CCCC2)C[N+]2(CCCCC2)C)ccc(C<unk>)c1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1(c2ccc(cc2)C<unk>)(CC[N+]2(C)CCCCC2)CCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1(c2ccc(cc2)C<unk>)(CC[N+]2(C)CCCCC2)CCCC1' for input: 'C1(c2ccc(cc2)C<unk>)(CC[N+]2(C)CCCCC2)CCCC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1(CCCC1)(c1ccccc1)C1(C[N+]1(C)CCCCCCC1)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CC(C[N+]2(C)CCCCCC2)(c2ccc(C<unk>)cc2)CCCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CC(C[N+]2(C)CCCCCC2)(c2ccc(C<unk>)cc2)CCCCC1' for input: 'C1CC(C[N+]2(C)CCCCCC2)(c2ccc(C<unk>)cc2)CCCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCC[N+](CCC1)(CC1(CCCC1)c1ccc(C<unk>)cc1)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCC[N+](CCC1)(CC1(CCCC1)c1ccc(C<unk>)cc1)C' for input: 'C1CCC[N+](CCC1)(CC1(CCCC1)c1ccc(C<unk>)cc1)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C(CCC1)(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C(CCC1)(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>' for input: 'C1C(CCC1)(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCC[N+](CC2(CCCC2)c2ccc(C<unk>)cc2)(CCCCCCC)C1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCC[N+](CC2(CCCC2)c2ccc(C<unk>)cc2)(CCCCCCC)C1' for input: 'C1CCCC[N+](CC2(CCCC2)c2ccc(C<unk>)cc2)(CCCCCCC)C1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C(c2ccc(cc2)C<unk>)(C[N+]2(C)CCCCCCCC2)CCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C(c2ccc(cc2)C<unk>)(C[N+]2(C)CCCCCCCC2)CCCC1' for input: 'C1C(c2ccc(cc2)C<unk>)(C[N+]2(C)CCCCCCCC2)CCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCCC1(C[N+]1(C)CCCCCCC1)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCCC1(C[N+]1(C)CCCCCCC1)c1ccc(C<unk>)cc1' for input: 'C1CCCCC1(C[N+]1(C)CCCCCCC1)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCC(C1)(C[N+]1(C)CCCCC1)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCC(C1)(C[N+]1(C)CCCCC1)c1ccc(C<unk>)cc1' for input: 'C1CCC(C1)(C[N+]1(C)CCCCC1)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1c(C<unk>)cccc1C1(CCCC1)C[N+]1(CCCCCCC1)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1c(C<unk>)cccc1C1(CCCC1)C[N+]1(CCCCCCC1)C' for input: 'c1c(C<unk>)cccc1C1(CCCC1)C[N+]1(CCCCCCC1)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 5
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CCC(C3[N+](CC2)(CC)CC)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12C(C3CC2CC3[N+](CCCC3)(CC)CC)CCC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1(C3)n1cc[n+](C34CC5CC(C4)CC(C4)C4)c1)C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC2C(CCC1)[N+](CC)(CC)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1(CC(C)CC(C1)C)[N+]1(CCCC)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C[N+]1(C2CCCC1CCC2)CCCC[N+]1(CCCCC1)CC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]1(CC(CC(C1)C)C)CC'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 6
# [01:51:53] SMILES Parse Error: syntax error while parsing: C[N+]1(CC2(c3ccc(C<unk>)cc3)CCCC2)CCCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C[N+]1(CC2(c3ccc(C<unk>)cc3)CCCC2)CCCCC1' for input: 'C[N+]1(CC2(c3ccc(C<unk>)cc3)CCCC2)CCCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC12
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC12' for input: 'C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC12'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C(C)[N+]1(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C(C)[N+]1(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1' for input: 'C(C)[N+]1(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCCC1' for input: 'C1[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C(CC1(C)C[N+]12CCCC1C)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C(CC1(C)C[N+]12CCCC1C)c1ccc(C<unk>)cc1' for input: 'C1C(CC1(C)C[N+]12CCCC1C)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1[N+](CCC1)(CC1(CC1)c1ccc(cc1)C<unk>)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1[N+](CCC1)(CC1(CC1)c1ccc(cc1)C<unk>)C' for input: 'C1[N+](CCC1)(CC1(CC1)c1ccc(cc1)C<unk>)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCC1' for input: 'C1C[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1CCCC[N+]1(CC1(CC1)c1ccc(C<unk>)cc1)CC
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1CCCC[N+]1(CC1(CC1)c1ccc(C<unk>)cc1)CC' for input: 'C1CCCC[N+]1(CC1(CC1)c1ccc(C<unk>)cc1)CC'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C[N+]1(CC2(c3cc(C<unk>)ccc3)CCCC2)CCCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C[N+]1(CC2(c3cc(C<unk>)ccc3)CCCC2)CCCCC1' for input: 'C[N+]1(CC2(c3cc(C<unk>)ccc3)CCCC2)CCCCC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: [N+]1(CCCC1)(CC1(CC1)c1ccc(C<unk>)cc1)CC
# [01:51:53] SMILES Parse Error: Failed parsing SMILES '[N+]1(CCCC1)(CC1(CC1)c1ccc(C<unk>)cc1)CC' for input: '[N+]1(CCCC1)(CC1(CC1)c1ccc(C<unk>)cc1)CC'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C[N+](CC2(c3ccc(cc3)C<unk>)CC2)(CCCC1)CC
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C[N+](CC2(c3ccc(cc3)C<unk>)CC2)(CCCC1)CC' for input: 'C1C[N+](CC2(c3ccc(cc3)C<unk>)CC2)(CCCC1)CC'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C(C1(CC2(c3ccc(C<unk>)cc3)CC1)CC1CC1CC2CC1)[N+]1(CC1CCCCC2)C
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C(C1(CC2(c3ccc(C<unk>)cc3)CC1)CC1CC1CC2CC1)[N+]1(CC1CCCCC2)C' for input: 'C(C1(CC2(c3ccc(C<unk>)cc3)CC1)CC1CC1CC2CC1)[N+]1(CC1CCCCC2)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1cc(C2(C[N+]3(CCCC3)CC)CC2)ccc1C<unk>
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1cc(C2(C[N+]3(CCCC3)CC)CC2)ccc1C<unk>' for input: 'c1cc(C2(C[N+]3(CCCC3)CC)CC2)ccc1C<unk>'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1(C[N+]2(CCCC2)CC)(c2ccc(C<unk>)cc2)CC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1(C[N+]2(CCCC2)CC)(c2ccc(C<unk>)cc2)CC1' for input: 'C1(C[N+]2(CCCC2)CC)(c2ccc(C<unk>)cc2)CC1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C([N+]1(CCCC1)C)C1(CC1)c1ccc(cc1)C<unk>
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C([N+]1(CCCC1)C)C1(CC1)c1ccc(cc1)C<unk>' for input: 'C([N+]1(CCCC1)C)C1(CC1)c1ccc(cc1)C<unk>'
# [01:51:53] SMILES Parse Error: syntax error while parsing: c1(C<unk>)ccc(cc1)C1(CC1)C[N+]1(CCCC1)CC
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'c1(C<unk>)ccc(cc1)C1(CC1)C[N+]1(CCCC1)CC' for input: 'c1(C<unk>)ccc(cc1)C1(CC1)C[N+]1(CCCC1)CC'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC1C2
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC1C2' for input: 'C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC1C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1(CC1)(CC1(C[N+]1(CC)CCCC1)C)C'
# [01:51:53] SMILES Parse Error: syntax error while parsing: [N+]1(CC2(c3ccc(C<unk>)cc3)CC1C2)(CC1)CC
# [01:51:53] SMILES Parse Error: Failed parsing SMILES '[N+]1(CC2(c3ccc(C<unk>)cc3)CC1C2)(CC1)CC' for input: '[N+]1(CC2(c3ccc(C<unk>)cc3)CC1C2)(CC1)CC'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1[N+](CC)(CC2(CC1)c1ccc(C<unk>)cc1)CC
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1[N+](CC)(CC2(CC1)c1ccc(C<unk>)cc1)CC' for input: 'C1[N+](CC)(CC2(CC1)c1ccc(C<unk>)cc1)CC'
# [01:51:53] SMILES Parse Error: syntax error while parsing: [N+]1(CC)(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES '[N+]1(CC)(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1' for input: '[N+]1(CC)(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1'
# [01:51:53] SMILES Parse Error: syntax error while parsing: C1(CC1(c1ccc(C<unk>)cc1)C<unk>)C1CCCCC1
# [01:51:53] SMILES Parse Error: Failed parsing SMILES 'C1(CC1(c1ccc(C<unk>)cc1)C<unk>)C1CCCCC1' for input: 'C1(CC1(c1ccc(C<unk>)cc1)C<unk>)C1CCCCC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCC([N+]21CCCC1CC(C2)(C)C)C'
# [01:51:53] SMILES Parse Error: ring closure 1 duplicates bond between atom 8 and atom 9 for input: 'C1CCC(CCCC1)[N+]1(C1CCCCC1)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCC2CC1[N+]1(CC)C(C)CCC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1([n+]1cn(cc1)C14CC5CC(CC(C5)C6)C1)CC(C2)C3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1CC([N+](C)(C)C)C3'
# [01:51:53] SMILES Parse Error: duplicated ring closure 5 bonds atom 13 to itself for input: 'C1C23C4C5C=CC(C4C5C[N+](C)(CC55)C)(C3C[N+]1(C)C)C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CCC(C34C4C5C(C[N+](C)(C5)C)C1C=C4)C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C123C4C=CC(C4)CC(C3)C2[N+](C)(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2C34CCCCC3(C=1CCCC2)C[N+]1(C)C'
# [01:51:53] SMILES Parse Error: ring closure 5 duplicates bond between atom 3 and atom 4 for input: 'C1C23C4C5C5C5C(C[N+](C5)(C)C)(C4C(C=C3)C2C1)C[N+](C)(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C23C=CC(CC13)C[N+]2(CCCC2)C'
# [01:51:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1(C3)n1cc[n+](C34CC5CC(CC(C4)C6)C5)c1)C2'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 11 14
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 15
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC(C)(CC(C[N+]3(C)C)C2)CC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1C[N+](C3)(C)CC(C2)C3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(C2)CC1([n+]1cn(C24CC5CC(CC(C4)C6)C4)cc1)C3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C[N+]3(C)CCCC3)C1CC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCC2[N+](C)(C)CC3CC2CC3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C[N+]1(CC23C4CCC(C2CCC1)C=C3)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1([n+]1cn(C45CC6CC(CC(C5)C7)C6)cc1)CC(C3)C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C2)C[N+](C3)(C)CC(C1)C3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC(C2(C)C)CCC[N+]2(C)CC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC2[N+](CC3CC(C3)C2CCCC[N+]2(C)C3)(C)CC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2([n+]3cn(cc3)C34CC5CC(C4)CC(C4)C6)CC3CC1CC(C3)C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC(C3N(CC1C3)CCCC2)C[N+]1(C)C2CCCC1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC(C)(C)C[N+]2(CC)CC(C)(C)C1C2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1(C)(C)C2CC1CC(C)(C)C2[N+]1(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C[N+]12CCCCC1CC1CC2CC2CC1'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 4 6 7
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1[N+](CC2C3C=CC(C4C3C3C[N+](C)(C3)C)C21)(C)C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCC2C3C(C12)CC1(C3CCCC1)CCCC3'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCC2C3CCCC4C3C(CC4(CCCC4)C3)CC12'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1C2(C)C(C3CCCCC3CC1CCC3)CCC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(CCCC3C2CCCC[N+]3(C)C2CCC1)C'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 2 3 7 8 9
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1(CN2CCN)ccncc1'
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 6 7 8
# [01:51:53] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C12CC(CC(C1)(C[N+]13CCCCC1)C)CCC2'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CC([N+]2(CCC(C2)C)CC)CC'
# [01:51:53] SMILES Parse Error: ring closure 3 duplicates bond between atom 10 and atom 19 for input: 'CC1CCC[N+]2(CCCC[N+]3(Cc4c(C2)cccc4)C3)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1(CC(C)C[N+]2(CCCC[N+]3(CCCC(C3)C)Cc3ccccc3)CCCC2)CCCC'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'c1cc2C[N+]3(CCC(C)CC3)CCCC1C'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2CCC[N+]3(C[N+]3(CC(CCC3)C)C2)C1'
# [01:51:53] SMILES Parse Error: unclosed ring for input: 'C1CCCC2C1CCCC[N+]12CCCCC2'
# ...
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCC(C[N+]2(C)CCCCCCC2)(c2ccc(C<unk>)cc2)C1' for input: 'C1CCC(C[N+]2(C)CCCCCCC2)(c2ccc(C<unk>)cc2)C1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCCC1(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCC1(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>' for input: 'C1CCCC1(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CC(C[N+]2(O)CCCC2)(F)c2ccc(C<unk>)cc2
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CC(C[N+]2(O)CCCC2)(F)c2ccc(C<unk>)cc2' for input: 'C1CC(C[N+]2(O)CCCC2)(F)c2ccc(C<unk>)cc2'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCCCCC[N+]1(C)CC1(c2ccc(cc2)C<unk>)CCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCCCC[N+]1(C)CC1(c2ccc(cc2)C<unk>)CCCC1' for input: 'C1CCCCCC[N+]1(C)CC1(c2ccc(cc2)C<unk>)CCCC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCCC1(c1ccc(C<unk>)cc1)C[N+]1(C)CCCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCC1(c1ccc(C<unk>)cc1)C[N+]1(C)CCCCC1' for input: 'C1CCCC1(c1ccc(C<unk>)cc1)C[N+]1(C)CCCCC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCCCC[N+](C)(CC2(CCCC2)c2ccc(cc2)C<unk>)C1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCCC[N+](C)(CC2(CCCC2)c2ccc(cc2)C<unk>)C1' for input: 'C1CCCCC[N+](C)(CC2(CCCC2)c2ccc(cc2)C<unk>)C1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: [N+]1(CCCCCCC1)(C)CC1(c2ccc(cc2)C<unk>)CCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES '[N+]1(CCCCCCC1)(C)CC1(c2ccc(cc2)C<unk>)CCCC1' for input: '[N+]1(CCCCCCC1)(C)CC1(c2ccc(cc2)C<unk>)CCCC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCCCC[N+]1(C)CC1(CCCC1)c1ccc(C<unk>)cc1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCCC[N+]1(C)CC1(CCCC1)c1ccc(C<unk>)cc1' for input: 'C1CCCCC[N+]1(C)CC1(CCCC1)c1ccc(C<unk>)cc1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: c1c(C2(CCCC2)C[N+]2(CCCCC2)C)ccc(C<unk>)c1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'c1c(C2(CCCC2)C[N+]2(CCCCC2)C)ccc(C<unk>)c1' for input: 'c1c(C2(CCCC2)C[N+]2(CCCCC2)C)ccc(C<unk>)c1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1(c2ccc(cc2)C<unk>)(CC[N+]2(C)CCCCC2)CCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1(c2ccc(cc2)C<unk>)(CC[N+]2(C)CCCCC2)CCCC1' for input: 'C1(c2ccc(cc2)C<unk>)(CC[N+]2(C)CCCCC2)CCCC1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1(CCCC1)(c1ccccc1)C1(C[N+]1(C)CCCCCCC1)C'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CC(C[N+]2(C)CCCCCC2)(c2ccc(C<unk>)cc2)CCCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CC(C[N+]2(C)CCCCCC2)(c2ccc(C<unk>)cc2)CCCCC1' for input: 'C1CC(C[N+]2(C)CCCCCC2)(c2ccc(C<unk>)cc2)CCCCC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCC[N+](CCC1)(CC1(CCCC1)c1ccc(C<unk>)cc1)C
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCC[N+](CCC1)(CC1(CCCC1)c1ccc(C<unk>)cc1)C' for input: 'C1CCC[N+](CCC1)(CC1(CCCC1)c1ccc(C<unk>)cc1)C'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1C(CCC1)(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1C(CCC1)(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>' for input: 'C1C(CCC1)(C[N+]1(C)CCCCCCC1)c1ccc(cc1)C<unk>'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCCC[N+](CC2(CCCC2)c2ccc(C<unk>)cc2)(CCCCCCC)C1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCC[N+](CC2(CCCC2)c2ccc(C<unk>)cc2)(CCCCCCC)C1' for input: 'C1CCCC[N+](CC2(CCCC2)c2ccc(C<unk>)cc2)(CCCCCCC)C1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1C(c2ccc(cc2)C<unk>)(C[N+]2(C)CCCCCCCC2)CCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1C(c2ccc(cc2)C<unk>)(C[N+]2(C)CCCCCCCC2)CCCC1' for input: 'C1C(c2ccc(cc2)C<unk>)(C[N+]2(C)CCCCCCCC2)CCCC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCCCC1(C[N+]1(C)CCCCCCC1)c1ccc(C<unk>)cc1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCCC1(C[N+]1(C)CCCCCCC1)c1ccc(C<unk>)cc1' for input: 'C1CCCCC1(C[N+]1(C)CCCCCCC1)c1ccc(C<unk>)cc1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCC(C1)(C[N+]1(C)CCCCC1)c1ccc(C<unk>)cc1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCC(C1)(C[N+]1(C)CCCCC1)c1ccc(C<unk>)cc1' for input: 'C1CCC(C1)(C[N+]1(C)CCCCC1)c1ccc(C<unk>)cc1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: c1c(C<unk>)cccc1C1(CCCC1)C[N+]1(CCCCCCC1)C
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'c1c(C<unk>)cccc1C1(CCCC1)C[N+]1(CCCCCCC1)C' for input: 'c1c(C<unk>)cccc1C1(CCCC1)C[N+]1(CCCCCCC1)C'
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 5
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2CCC(C3[N+](CC2)(CC)CC)C1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C12C(C3CC2CC3[N+](CCCC3)(CC)CC)CCC1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1(C3)n1cc[n+](C34CC5CC(C4)CC(C4)C4)c1)C2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CC2C(CCC1)[N+](CC)(CC)CC'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1(CC(C)CC(C1)C)[N+]1(CCCC)CC'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C[N+]1(C2CCCC1CCC2)CCCC[N+]1(CCCCC1)CC2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CC[N+]1(CC(CC(C1)C)C)CC'
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 6
# [01:53:00] SMILES Parse Error: syntax error while parsing: C[N+]1(CC2(c3ccc(C<unk>)cc3)CCCC2)CCCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C[N+]1(CC2(c3ccc(C<unk>)cc3)CCCC2)CCCCC1' for input: 'C[N+]1(CC2(c3ccc(C<unk>)cc3)CCCC2)CCCCC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC12
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC12' for input: 'C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC12'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C(C)[N+]1(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C(C)[N+]1(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1' for input: 'C(C)[N+]1(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCCC1' for input: 'C1[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCCC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1C(CC1(C)C[N+]12CCCC1C)c1ccc(C<unk>)cc1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1C(CC1(C)C[N+]12CCCC1C)c1ccc(C<unk>)cc1' for input: 'C1C(CC1(C)C[N+]12CCCC1C)c1ccc(C<unk>)cc1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1[N+](CCC1)(CC1(CC1)c1ccc(cc1)C<unk>)C
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1[N+](CCC1)(CC1(CC1)c1ccc(cc1)C<unk>)C' for input: 'C1[N+](CCC1)(CC1(CC1)c1ccc(cc1)C<unk>)C'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1C[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1C[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCC1' for input: 'C1C[N+](CC)(CC2(c3ccc(C<unk>)cc3)CC2)CCC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1CCCC[N+]1(CC1(CC1)c1ccc(C<unk>)cc1)CC
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1CCCC[N+]1(CC1(CC1)c1ccc(C<unk>)cc1)CC' for input: 'C1CCCC[N+]1(CC1(CC1)c1ccc(C<unk>)cc1)CC'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C[N+]1(CC2(c3cc(C<unk>)ccc3)CCCC2)CCCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C[N+]1(CC2(c3cc(C<unk>)ccc3)CCCC2)CCCCC1' for input: 'C[N+]1(CC2(c3cc(C<unk>)ccc3)CCCC2)CCCCC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: [N+]1(CCCC1)(CC1(CC1)c1ccc(C<unk>)cc1)CC
# [01:53:00] SMILES Parse Error: Failed parsing SMILES '[N+]1(CCCC1)(CC1(CC1)c1ccc(C<unk>)cc1)CC' for input: '[N+]1(CCCC1)(CC1(CC1)c1ccc(C<unk>)cc1)CC'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1C[N+](CC2(c3ccc(cc3)C<unk>)CC2)(CCCC1)CC
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1C[N+](CC2(c3ccc(cc3)C<unk>)CC2)(CCCC1)CC' for input: 'C1C[N+](CC2(c3ccc(cc3)C<unk>)CC2)(CCCC1)CC'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C(C1(CC2(c3ccc(C<unk>)cc3)CC1)CC1CC1CC2CC1)[N+]1(CC1CCCCC2)C
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C(C1(CC2(c3ccc(C<unk>)cc3)CC1)CC1CC1CC2CC1)[N+]1(CC1CCCCC2)C' for input: 'C(C1(CC2(c3ccc(C<unk>)cc3)CC1)CC1CC1CC2CC1)[N+]1(CC1CCCCC2)C'
# [01:53:00] SMILES Parse Error: syntax error while parsing: c1cc(C2(C[N+]3(CCCC3)CC)CC2)ccc1C<unk>
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'c1cc(C2(C[N+]3(CCCC3)CC)CC2)ccc1C<unk>' for input: 'c1cc(C2(C[N+]3(CCCC3)CC)CC2)ccc1C<unk>'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1(C[N+]2(CCCC2)CC)(c2ccc(C<unk>)cc2)CC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1(C[N+]2(CCCC2)CC)(c2ccc(C<unk>)cc2)CC1' for input: 'C1(C[N+]2(CCCC2)CC)(c2ccc(C<unk>)cc2)CC1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C([N+]1(CCCC1)C)C1(CC1)c1ccc(cc1)C<unk>
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C([N+]1(CCCC1)C)C1(CC1)c1ccc(cc1)C<unk>' for input: 'C([N+]1(CCCC1)C)C1(CC1)c1ccc(cc1)C<unk>'
# [01:53:00] SMILES Parse Error: syntax error while parsing: c1(C<unk>)ccc(cc1)C1(CC1)C[N+]1(CCCC1)CC
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'c1(C<unk>)ccc(cc1)C1(CC1)C[N+]1(CCCC1)CC' for input: 'c1(C<unk>)ccc(cc1)C1(CC1)C[N+]1(CCCC1)CC'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC1C2
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC1C2' for input: 'C1C[N+](CC)(CC)CC2(c3ccc(cc3)C<unk>)CC1C2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1(CC1)(CC1(C[N+]1(CC)CCCC1)C)C'
# [01:53:00] SMILES Parse Error: syntax error while parsing: [N+]1(CC2(c3ccc(C<unk>)cc3)CC1C2)(CC1)CC
# [01:53:00] SMILES Parse Error: Failed parsing SMILES '[N+]1(CC2(c3ccc(C<unk>)cc3)CC1C2)(CC1)CC' for input: '[N+]1(CC2(c3ccc(C<unk>)cc3)CC1C2)(CC1)CC'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1[N+](CC)(CC2(CC1)c1ccc(C<unk>)cc1)CC
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1[N+](CC)(CC2(CC1)c1ccc(C<unk>)cc1)CC' for input: 'C1[N+](CC)(CC2(CC1)c1ccc(C<unk>)cc1)CC'
# [01:53:00] SMILES Parse Error: syntax error while parsing: [N+]1(CC)(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES '[N+]1(CC)(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1' for input: '[N+]1(CC)(CCCC1)CC1(CC1)c1ccc(C<unk>)cc1'
# [01:53:00] SMILES Parse Error: syntax error while parsing: C1(CC1(c1ccc(C<unk>)cc1)C<unk>)C1CCCCC1
# [01:53:00] SMILES Parse Error: Failed parsing SMILES 'C1(CC1(c1ccc(C<unk>)cc1)C<unk>)C1CCCCC1' for input: 'C1(CC1(c1ccc(C<unk>)cc1)C<unk>)C1CCCCC1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CCCC([N+]21CCCC1CC(C2)(C)C)C'
# [01:53:00] SMILES Parse Error: ring closure 1 duplicates bond between atom 8 and atom 9 for input: 'C1CCC(CCCC1)[N+]1(C1CCCCC1)CC'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CCCC2CC1[N+]1(CC)C(C)CCC1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1([n+]1cn(cc1)C14CC5CC(CC(C5)C6)C1)CC(C2)C3'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1CC([N+](C)(C)C)C3'
# [01:53:00] SMILES Parse Error: duplicated ring closure 5 bonds atom 13 to itself for input: 'C1C23C4C5C=CC(C4C5C[N+](C)(CC55)C)(C3C[N+]1(C)C)C2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C12CCC(C34C4C5C(C[N+](C)(C5)C)C1C=C4)C2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C123C4C=CC(C4)CC(C3)C2[N+](C)(C)C'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2C34CCCCC3(C=1CCCC2)C[N+]1(C)C'
# [01:53:00] SMILES Parse Error: ring closure 5 duplicates bond between atom 3 and atom 4 for input: 'C1C23C4C5C5C5C(C[N+](C5)(C)C)(C4C(C=C3)C2C1)C[N+](C)(C)C'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C23C=CC(CC13)C[N+]2(CCCC2)C'
# [01:53:00] Explicit valence for atom # 1 C, 5, is greater than permitted
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(CC1(C3)n1cc[n+](C34CC5CC(CC(C4)C6)C5)c1)C2'
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 0 11 14
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 15
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C12CC(C)(CC(C[N+]3(C)C)C2)CC1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1C[N+](C3)(C)CC(C2)C3'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC(C2)CC1([n+]1cn(C24CC5CC(CC(C4)C6)C4)cc1)C3'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C[N+]3(C)CCCC3)C1CC2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CCC2[N+](C)(C)CC3CC2CC3'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C[N+]1(CC23C4CCC(C2CCC1)C=C3)C'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2CC3CC1([n+]1cn(C45CC6CC(CC(C5)C7)C6)cc1)CC(C3)C2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C12CC3CC(C2)C[N+](C3)(C)CC(C1)C3'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C12CC(C2(C)C)CCC[N+]2(C)CC'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CC2[N+](CC3CC(C3)C2CCCC[N+]2(C)C3)(C)CC1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2([n+]3cn(cc3)C34CC5CC(C4)CC(C4)C6)CC3CC1CC(C3)C2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C12CC(C3N(CC1C3)CCCC2)C[N+]1(C)C2CCCC1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C12CC(C)(C)C[N+]2(CC)CC(C)(C)C1C2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1(C)(C)C2CC1CC(C)(C)C2[N+]1(C)C'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C[N+]12CCCCC1CC1CC2CC2CC1'
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 0 1 4 6 7
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1[N+](CC2C3C=CC(C4C3C3C[N+](C)(C3)C)C21)(C)C'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CCC2C3C(C12)CC1(C3CCCC1)CCCC3'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CCCC2C3CCCC4C3C(CC4(CCCC4)C3)CC12'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C2(C)C(C3CCCCC3CC1CCC3)CCC2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1[N+]2(CCCC3C2CCCC[N+]3(C)C2CCC1)C'
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 2 3 7 8 9
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'c1(CN2CCN)ccncc1'
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 0 1 6 7 8
# [01:53:00] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C12CC(CC(C1)(C[N+]13CCCCC1)C)CCC2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CC([N+]2(CCC(C2)C)CC)CC'
# [01:53:00] SMILES Parse Error: ring closure 3 duplicates bond between atom 10 and atom 19 for input: 'CC1CCC[N+]2(CCCC[N+]3(Cc4c(C2)cccc4)C3)C1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1(CC(C)C[N+]2(CCCC[N+]3(CCCC(C3)C)Cc3ccccc3)CCCC2)CCCC'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'c1cc2C[N+]3(CCC(C)CC3)CCCC1C'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CCCCC2CCC[N+]3(C[N+]3(CC(CCC3)C)C2)C1'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CCCC2C1CCCC[N+]12CCCCC2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1CCCC2C1CCC[N+]21CCCCC2'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C(C)(C)CC2CC1(C)C[N+]21CCCCC2'
# [01:53:00] SMILES Parse Error: ring closure 1 duplicates bond between atom 7 and atom 8 for input: 'C1C2[N+](C3CC1CC1[N+]1(C)C(C2)CCCC1)(C3)C'
# [01:53:00] SMILES Parse Error: unclosed ring for input: 'C1C[N+]2(C)C(CC3[N+]4(C)C(CC2CCC1)C3)C'
# [01:53:00] SMILES Parse Error: ring closure 2 duplicates bond between atom 11 and atom 12 for input: 'C1CCCC2[N+]1(CC1CC2CC2[N+]2(C)CCCCC1)C'
# FCD score: 0.2734091554161502

# %%
# plot the loss and acc
plot_loss(train_loss_history, test_loss_history, 'Clamer_contrastive_loss')

# %%
# save the history to the csv file in log folder
history = pd.DataFrame({'train_loss': train_loss_history, 'train_acc': train_acc_history, 'test_loss': test_loss_history, 'test_acc': test_acc_history, 'train_ce_loss': train_ce_loss_history, 'test_ce_loss': test_ce_loss_history, 'train_info_loss': train_info_loss_history, 'test_info_loss': test_info_loss_history})
history.to_csv(log_dir + 'clamer_contrastive_history.csv', index=False)
